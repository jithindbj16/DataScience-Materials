# %% [markdown]
# # Read & Plot Time Series Data

# %%
import pandas as pd
import datetime as dt
import numpy as np
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15,6
from patsy import dmatrices
from pandas import Series
from matplotlib import pyplot
from datetime import datetime
from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 12), dpi=80, facecolor='w', edgecolor='k')

# %% [markdown]
# # Read yearly time series: USGDP

# %%
USGDP = pd.read_csv('GDPUS.csv')
USGDP.head(8)
# Out:
#    Year    GDP
# 0  1929  821.8
# 1  1930  748.9
# 2  1931  691.3
# 3  1932  599.7
# 4  1933  587.1
# 5  1934  632.6
# 6  1935  681.6
# 7  1936  777.9

# %%
USGDP.tail(5)
# Out:
#     Year     GDP
# 58  1987  4718.6
# 59  1988  4784.6
# 60  1989  4739.2
# 61  1990  4822.3
# 62  1991  4835.0

# %%
date_rng = pd.date_range(start='1/1/1929', end='31/12/1991', freq='Y')   # y stands for year
date_rng
# Out:
# DatetimeIndex(['1929-12-31', '1930-12-31', '1931-12-31', '1932-12-31',
#                '1933-12-31', '1934-12-31', '1935-12-31', '1936-12-31',
#                '1937-12-31', '1938-12-31', '1939-12-31', '1940-12-31',
#                '1941-12-31', '1942-12-31', '1943-12-31', '1944-12-31',
#                '1945-12-31', '1946-12-31', '1947-12-31', '1948-12-31',
#                '1949-12-31', '1950-12-31', '1951-12-31', '1952-12-31',
#                '1953-12-31', '1954-12-31', '1955-12-31', '1956-12-31',
#                '1957-12-31', '1958-12-31', '1959-12-31', '1960-12-31',
#                '1961-12-31', '1962-12-31', '1963-12-31', '1964-12-31',
#                '1965-12-31', '1966-12-31', '1967-12-31', '1968-12-31',
#                '1969-12-31', '1970-12-31', '1971-12-31', '1972-12-31',
#                '1973-12-31', '1974-12-31', '1975-12-31', '1976-12-31',
#                '1977-12-31', '1978-12-31', '1979-12-31', '1980-12-31',
# ...

# %%
USGDP['TimeIndex'] = pd.DataFrame(date_rng, columns=['Year'])
USGDP.head(8)
# Out:
#    Year    GDP  TimeIndex
# 0  1929  821.8 1929-12-31
# 1  1930  748.9 1930-12-31
# 2  1931  691.3 1931-12-31
# 3  1932  599.7 1932-12-31
# 4  1933  587.1 1933-12-31
# 5  1934  632.6 1934-12-31
# 6  1935  681.6 1935-12-31
# 7  1936  777.9 1936-12-31

# %%
plt.plot(USGDP.TimeIndex, USGDP.GDP)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 1: Read GDP India series

# %%
india=pd.read_csv('GDPIndia.csv')
india.head()
# Out:
#    Year  GDPpercapita
# 0  1960     81.284764
# 1  1961     84.426437
# 2  1962     88.914919
# 3  1963    100.048592
# 4  1964    114.315161

# %%
india.tail()
# Out:
#     Year  GDPpercapita
# 53  2013   1452.195373
# 54  2014   1576.004018
# 55  2015   1606.038285
# 56  2016   1717.473878
# 57  2017   1939.612984

# %%
date_rng = pd.date_range(start='1/1/1960', end='31/12/2017', freq='Y')   # y stands for year
date_rng
# Out:
# DatetimeIndex(['1960-12-31', '1961-12-31', '1962-12-31', '1963-12-31',
#                '1964-12-31', '1965-12-31', '1966-12-31', '1967-12-31',
#                '1968-12-31', '1969-12-31', '1970-12-31', '1971-12-31',
#                '1972-12-31', '1973-12-31', '1974-12-31', '1975-12-31',
#                '1976-12-31', '1977-12-31', '1978-12-31', '1979-12-31',
#                '1980-12-31', '1981-12-31', '1982-12-31', '1983-12-31',
#                '1984-12-31', '1985-12-31', '1986-12-31', '1987-12-31',
#                '1988-12-31', '1989-12-31', '1990-12-31', '1991-12-31',
#                '1992-12-31', '1993-12-31', '1994-12-31', '1995-12-31',
#                '1996-12-31', '1997-12-31', '1998-12-31', '1999-12-31',
#                '2000-12-31', '2001-12-31', '2002-12-31', '2003-12-31',
#                '2004-12-31', '2005-12-31', '2006-12-31', '2007-12-31',
#                '2008-12-31', '2009-12-31', '2010-12-31', '2011-12-31',
# ...

# %%
india['TimeIndex'] = pd.DataFrame(date_rng, columns=['Year'])
india.head(8)
# Out:
#    Year  GDPpercapita  TimeIndex
# 0  1960     81.284764 1960-12-31
# 1  1961     84.426437 1961-12-31
# 2  1962     88.914919 1962-12-31
# 3  1963    100.048592 1963-12-31
# 4  1964    114.315161 1964-12-31
# 5  1965    118.063382 1965-12-31
# 6  1966     89.053583 1966-12-31
# 7  1967     95.330783 1967-12-31

# %%
plt.plot(india.TimeIndex, india.GDPpercapita)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 2: Read English Daily Wage series

# %%
engdaily=pd.read_csv('EngWage.csv')
engdaily.head()
# Out:
#    Year  DailyWage
# 0  1950      24.27
# 1  1951      24.17
# 2  1952      23.76
# 3  1953      24.17
# 4  1954      25.18

# %%
engdaily.tail()
# Out:
#     Year  DailyWage
# 40  1990      46.19
# 41  1991      46.86
# 42  1992      49.42
# 43  1993      49.51
# 44  1994      49.99

# %%
date_rng = pd.date_range(start='1/1/1950', end='31/12/1994', freq='Y')   # y stands for year
date_rng
# Out:
# DatetimeIndex(['1950-12-31', '1951-12-31', '1952-12-31', '1953-12-31',
#                '1954-12-31', '1955-12-31', '1956-12-31', '1957-12-31',
#                '1958-12-31', '1959-12-31', '1960-12-31', '1961-12-31',
#                '1962-12-31', '1963-12-31', '1964-12-31', '1965-12-31',
#                '1966-12-31', '1967-12-31', '1968-12-31', '1969-12-31',
#                '1970-12-31', '1971-12-31', '1972-12-31', '1973-12-31',
#                '1974-12-31', '1975-12-31', '1976-12-31', '1977-12-31',
#                '1978-12-31', '1979-12-31', '1980-12-31', '1981-12-31',
#                '1982-12-31', '1983-12-31', '1984-12-31', '1985-12-31',
#                '1986-12-31', '1987-12-31', '1988-12-31', '1989-12-31',
#                '1990-12-31', '1991-12-31', '1992-12-31', '1993-12-31',
#                '1994-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
engdaily['TimeIndex'] = pd.DataFrame(date_rng, columns=['Year'])
engdaily.head(8)
# Out:
#    Year  DailyWage  TimeIndex
# 0  1950      24.27 1950-12-31
# 1  1951      24.17 1951-12-31
# 2  1952      23.76 1952-12-31
# 3  1953      24.17 1953-12-31
# 4  1954      25.18 1954-12-31
# 5  1955      25.74 1955-12-31
# 6  1956      26.19 1956-12-31
# 7  1957      26.68 1957-12-31

# %%
plt.plot(engdaily.TimeIndex, engdaily.DailyWage)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Read Quarterly Time Series: Retail Turnover

# %%
Turnover = pd.read_csv('RetailTurnover.csv')
Turnover.head()
# Out:
#    Year Quarter  Turnover
# 0  1982      Q3   13423.2
# 1  1982      Q4   13128.8
# 2  1983      Q1   15398.8
# 3  1983      Q2   12964.2
# 4  1983      Q3   13133.5

# %%
from datetime import datetime
date_rng = pd.date_range(start='1/7/1982', end='31/3/1992', freq='Q')   # Q is for quarter

# %%
date_rng
# Out:
# DatetimeIndex(['1982-03-31', '1982-06-30', '1982-09-30', '1982-12-31',
#                '1983-03-31', '1983-06-30', '1983-09-30', '1983-12-31',
#                '1984-03-31', '1984-06-30', '1984-09-30', '1984-12-31',
#                '1985-03-31', '1985-06-30', '1985-09-30', '1985-12-31',
#                '1986-03-31', '1986-06-30', '1986-09-30', '1986-12-31',
#                '1987-03-31', '1987-06-30', '1987-09-30', '1987-12-31',
#                '1988-03-31', '1988-06-30', '1988-09-30', '1988-12-31',
#                '1989-03-31', '1989-06-30', '1989-09-30', '1989-12-31',
#                '1990-03-31', '1990-06-30', '1990-09-30', '1990-12-31',
#                '1991-03-31', '1991-06-30', '1991-09-30', '1991-12-31',
#                '1992-03-31'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
Turnover['TimeIndex'] = pd.DataFrame(date_rng, columns=['Quarter'])
Turnover.head()
# Out:
#    Year Quarter  Turnover  TimeIndex
# 0  1982      Q3   13423.2 1982-03-31
# 1  1982      Q4   13128.8 1982-06-30
# 2  1983      Q1   15398.8 1982-09-30
# 3  1983      Q2   12964.2 1982-12-31
# 4  1983      Q3   13133.5 1983-03-31

# %%
plt.plot(Turnover.TimeIndex, Turnover.Turnover)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 3: Read Portugal Port Series

# %%
port=pd.read_csv('PortugalPort.csv')
port.head()
# Out:
#    Year Quarter  Pax
# 0  2000      Q1   21
# 1  2000      Q2   61
# 2  2000      Q3  119
# 3  2000      Q4   30
# 4  2001      Q1   16

# %%
port.tail()
# Out:
#     Year Quarter  Pax
# 67  2016      Q4   54
# 68  2017      Q1   29
# 69  2017      Q2   96
# 70  2017      Q3  152
# 71  2017      Q4   61

# %%
date_rng = pd.date_range(start='1/1/2000', end='31/12/2017', freq='Q')

# %%
port['TimeIndex'] = pd.DataFrame(date_rng, columns=['Quarter'])
port.head()
# Out:
#    Year Quarter  Pax  TimeIndex
# 0  2000      Q1   21 2000-03-31
# 1  2000      Q2   61 2000-06-30
# 2  2000      Q3  119 2000-09-30
# 3  2000      Q4   30 2000-12-31
# 4  2001      Q1   16 2001-03-31

# %%
plt.plot(port.TimeIndex, port.Pax)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 4: Read Petrol Consumption Series

# %%
petrol=pd.read_csv('Petrol.csv')
petrol.tail()
# Out:
#     Year Quarter  Consumption
# 46  2012      Q3      0.88818
# 47  2012      Q4      0.99804
# 48  2013      Q1      0.84120
# 49  2013      Q2      0.74032
# 50  2013      Q3      0.72823

# %%
petrol.head()
# Out:
#    Year Quarter  Consumption
# 0  2001      Q1       14.978
# 1  2001      Q2       11.099
# 2  2001      Q3       10.057
# 3  2001      Q4       10.454
# 4  2002      Q1        9.295

# %%
date_rng = pd.date_range(start='1/1/2001', end='31/12/2013', freq='Q')

# %%
petrol['TimeIndex'] = pd.DataFrame(date_rng, columns=['Quarter'])
petrol.head()
# Out:
#    Year Quarter  Consumption  TimeIndex
# 0  2001      Q1       14.978 2001-03-31
# 1  2001      Q2       11.099 2001-06-30
# 2  2001      Q3       10.057 2001-09-30
# 3  2001      Q4       10.454 2001-12-31
# 4  2002      Q1        9.295 2002-03-31

# %%
plt.plot(petrol.TimeIndex, petrol.Consumption)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Read Monthly Time Series: Average Monthly Temperature

# %%
AirTemp = pd.read_csv('AirTemp.csv')
#AirTemp.head()

# %%
date_rng = pd.date_range(start='1/1/1920', end='31/12/1939', freq='M') # M is for monthly
#date_rng

# %%
AirTemp['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
AirTemp.head()
# Out:
#    Year Month  AvgTemp  TimeIndex
# 0  1920   Jan     40.6 1920-01-31
# 1  1920   Feb     40.8 1920-02-29
# 2  1920   Mar     44.4 1920-03-31
# 3  1920   Apr     46.7 1920-04-30
# 4  1920   May     54.1 1920-05-31

# %%
plt.plot(AirTemp.TimeIndex, AirTemp.AvgTemp)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 5: Read Champagne Series

# %%
cham=pd.read_csv('Champagne.csv')
cham.head()
# Out:
#    Year Month  Sales
# 0  1964   Jan   2815
# 1  1964   Feb   2672
# 2  1964   Mar   2755
# 3  1964   Apr   2721
# 4  1964   May   2946

# %%
cham.tail()
# Out:
#      Year Month  Sales
# 100  1972   May   4618
# 101  1972   Jun   5312
# 102  1972   Jul   4298
# 103  1972   Aug   1413
# 104  1972   Sep   5877

# %%
date_rng = pd.date_range(start='1/1/1964', end='31/12/1972', freq='M')

# %%
cham['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
cham.head()
# Out:
#    Year Month  Sales  TimeIndex
# 0  1964   Jan   2815 1964-01-31
# 1  1964   Feb   2672 1964-02-29
# 2  1964   Mar   2755 1964-03-31
# 3  1964   Apr   2721 1964-04-30
# 4  1964   May   2946 1964-05-31

# %%
plt.plot(cham.TimeIndex, cham.Sales)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 6: Read International Air Passengers Data

# %%
air=pd.read_csv('AirPassenger.csv')
air.head()
# Out:
#   Year-Month  International Airlines Pax
# 0    1949-01                         112
# 1    1949-02                         118
# 2    1949-03                         132
# 3    1949-04                         129
# 4    1949-05                         121

# %%
air.tail()
# Out:
#     Year-Month  International Airlines Pax
# 139    1960-08                         606
# 140    1960-09                         508
# 141    1960-10                         461
# 142    1960-11                         390
# 143    1960-12                         432

# %%
date_rng = pd.date_range(start='1/1/1949', end='31/12/1960', freq='M')

# %%
air['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
air.head()
# Out:
#   Year-Month  International Airlines Pax  TimeIndex
# 0    1949-01                         112 1949-01-31
# 1    1949-02                         118 1949-02-28
# 2    1949-03                         132 1949-03-31
# 3    1949-04                         129 1949-04-30
# 4    1949-05                         121 1949-05-31

# %%
plt.plot(air.TimeIndex, air['International Airlines Pax'])
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 7: Read Tractor Sales Series

# %%
Tractor = pd.read_csv("TractorSales.csv")
Tractor.head(5)
# Out:
#   Month-Year  Number of Tractor Sold
# 0      3-Jan                     141
# 1      3-Feb                     157
# 2      3-Mar                     185
# 3      3-Apr                     199
# 4      3-May                     203

# %%
dates = pd.date_range(start='2003-01-01', freq='MS', periods=len(Tractor))

# %%
import calendar
Tractor['Month'] = dates.month
Tractor['Month'] = Tractor['Month'].apply(lambda x: calendar.month_abbr[x])
Tractor['Year'] = dates.year

# %%
#Tractor.drop(['Month-Year'], axis=1, inplace=True)
Tractor.rename(columns={'Number of Tractor Sold':'Tractor-Sales'}, inplace=True)
Tractor = Tractor[['Month', 'Year', 'Tractor-Sales']]

# %%
Tractor.set_index(dates, inplace=True)

# %%
Tractor.head(5)
# Out:
#            Month  Year  Tractor-Sales
# 2003-01-01   Jan  2003            141
# 2003-02-01   Feb  2003            157
# 2003-03-01   Mar  2003            185
# 2003-04-01   Apr  2003            199
# 2003-05-01   May  2003            203

# %%
# extract out the time-series
sales_ts = Tractor['Tractor-Sales']

# %%
plt.figure(figsize=(8, 4))
plt.plot(sales_ts)
plt.xlabel('Years')
plt.ylabel('Tractor Sales')
# Out:
# Text(0,0.5,'Tractor Sales')

# %% [markdown]
# # Task 8: Read Environmental CO2 Emission Series

# %% [markdown]
# # Task 9: Reading Retal Food Sales Series

# %% [markdown]
# # Task 10: Reading Mauna Loa Emission Series

# %%
mauna=pd.read_csv('MaunaLoa.csv')
mauna.head()
# Out:
#    Year Month  CO2 ppm
# 0  1965   Jan   319.32
# 1  1965   Feb   320.36
# 2  1965   Mar   320.82
# 3  1965   Apr   322.06
# 4  1965   May   322.17

# %%
mauna.tail()
# Out:
#      Year Month  CO2 ppm
# 187  1980   Aug   337.19
# 188  1980   Sep   335.49
# 189  1980   Oct   336.63
# 190  1980   Nov   337.74
# 191  1980   Dec   338.36

# %%
date_rng=pd.date_range(start='1/1/1965',end='31/12/1980',freq='M')
mauna['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
mauna.head()
# Out:
#    Year Month  CO2 ppm  TimeIndex
# 0  1965   Jan   319.32 1965-01-31
# 1  1965   Feb   320.36 1965-02-28
# 2  1965   Mar   320.82 1965-03-31
# 3  1965   Apr   322.06 1965-04-30
# 4  1965   May   322.17 1965-05-31

# %%
plt.plot(mauna.TimeIndex, mauna['CO2 ppm'])
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Reading Weekly Time Series: Dow Jones Closing

# %%
DJI = pd.read_csv("WeeklyClosing.csv")
DJI.head(5)
# Out:
#          Week  Closing
# 0  1971-07-05   890.19
# 1  1971-07-12   901.80
# 2  1971-07-19   888.51
# 3  1971-07-26   887.78
# 4  1971-08-02   858.43

# %%
date_rng = pd.date_range(start='7/4/1971', end='8/5/1974', freq='W')
DJI['TimeIndex'] = pd.DataFrame(date_rng, columns=['Week'])
DJI.rename(columns={'DJIA Closing':'Closing'}, inplace=True)
DJI.head()
# Out:
#          Week  Closing  TimeIndex
# 0  1971-07-05   890.19 1971-07-04
# 1  1971-07-12   901.80 1971-07-11
# 2  1971-07-19   888.51 1971-07-18
# 3  1971-07-26   887.78 1971-07-25
# 4  1971-08-02   858.43 1971-08-01

# %%
plt.plot(DJI.TimeIndex, DJI.Closing)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 11: Reading Gasoline Price Data

# %% [markdown]
# # Read Week-Day Time Series: Crude Oil Production

# %%
CrdOil = pd.read_csv('CrudeOil.csv')
CrdOil.head()
# Out:
#          Date  Weekday  Price
# 0  1983-04-04        2  29.44
# 1  1983-04-05        3  29.71
# 2  1983-04-06        4  29.92
# 3  1983-04-07        5  30.17
# 4  1983-04-08        6  30.38

# %%
date_rng = pd.date_range(start='4/4/1983', end='27/11/2012', freq='B')
#date_rng

# %%
CrdOil['TimeIndex'] = pd.DataFrame(date_rng, columns=['Weekday'])
CrdOil.head()
# Out:
#          Date  Weekday  Price  TimeIndex
# 0  1983-04-04        2  29.44 1983-04-04
# 1  1983-04-05        3  29.71 1983-04-05
# 2  1983-04-06        4  29.92 1983-04-06
# 3  1983-04-07        5  30.17 1983-04-07
# 4  1983-04-08        6  30.38 1983-04-08

# %%
plt.plot(CrdOil.TimeIndex, CrdOil.Price)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Simple Forecasts: Average and Moving Average

# %% [markdown]
# # AirTemp, US GDP, India GDP, Eng Daily Wage

# %%
temp_avg = AirTemp.copy()
temp_avg['avg_forecast'] = AirTemp['AvgTemp'].mean()

# %%
plt.figure(figsize=(12,8))
plt.plot(AirTemp['AvgTemp'], label='Data')
plt.plot(temp_avg['avg_forecast'], label='Average Forecast')
plt.legend(loc='best')

# %%
mvg_avg = AirTemp.copy()
mvg_avg['moving_avg_forecast'] = AirTemp['AvgTemp'].rolling(12).mean()
#mvg_avg.head(15)
#mvg_avg.tail(6)

# %%
#plt.figure(figsize=(16,8))
plt.plot(AirTemp['AvgTemp'], label='Average Temperature')
plt.plot(mvg_avg['moving_avg_forecast'], label='Moving Average Forecast')
plt.legend(loc='best')

# %% [markdown]
# # Task 1: MA(5) for US GDP

# %%
mvg=USGDP.copy()
mvg['moving_avg_forecast']=USGDP['GDP'].rolling(5).mean()
plt.plot(USGDP['GDP'],label='US GDP')
plt.plot(mvg['moving_avg_forecast'],label='US GDP MA($)')
plt.legend(loc='best')

# %%
mvg=USGDP.copy()
mvg['moving_avg_forecast']=USGDP['GDP'].rolling(7).mean()
plt.plot(USGDP['GDP'],label='US GDP')
plt.plot(mvg['moving_avg_forecast'],label='US GDP MA($)')
plt.legend(loc='best')

# %%
mvg=USGDP.copy()
mvg['moving_avg_forecast']=USGDP['GDP'].rolling(11).mean()
plt.plot(USGDP['GDP'],label='US GDP')
plt.plot(mvg['moving_avg_forecast'],label='US GDP MA($)')
plt.legend(loc='best')

# %%
mvg=USGDP.copy()
mvg['moving_avg_forecast']=USGDP['GDP'].rolling(17).mean()
plt.plot(USGDP['GDP'],label='US GDP')
plt.plot(mvg['moving_avg_forecast'],label='US GDP MA($)')
plt.legend(loc='best')

# %% [markdown]
# # Task 2: MA(3) for India GDP

# %%
mvg=india.copy()
mvg['moving_avg_forecast']=india['GDPpercapita'].rolling(3).mean()
plt.plot(india['GDPpercapita'],label='India GDP per capita')
plt.plot(mvg['moving_avg_forecast'],label='India GDP/Capita MA(3)')
plt.legend(loc='best')

# %% [markdown]
# # Task 2: MA(7) for Daily Wage

# %% [markdown]
# # MA Forecast for Crude Oil

# %%
mvg_avg_oil1 = CrdOil.copy()
mvg_avg_oil2 = CrdOil.copy()
mvg_avg_oil3 = CrdOil.copy()

mvg_avg_oil1['moving_avg_forecast'] = CrdOil['Price'].rolling(300).mean()
mvg_avg_oil2['moving_avg_forecast'] = CrdOil['Price'].rolling(900).mean()
mvg_avg_oil3['moving_avg_forecast'] = CrdOil['Price'].rolling(1500).mean()

# %%
plt.figure(figsize=(16,8))
plt.plot(CrdOil['Price'], label='Crude Oil Price')
plt.plot(mvg_avg_oil1['moving_avg_forecast'], label='MA(300)')
plt.plot(mvg_avg_oil2['moving_avg_forecast'], label='MA(900)')
plt.plot(mvg_avg_oil3['moving_avg_forecast'], label='MA(1500)')
plt.legend(loc='upper left')

# %% [markdown]
# # Visualization of Seasonality: Quarterly Turnover

# %%
quarterly_turnover = pd.pivot_table(Turnover, values = "Turnover", columns = "Quarter", index = "Year")
quarterly_turnover
# Out:
# Quarter       Q1       Q2       Q3       Q4
# Year
# 1982         NaN      NaN  13423.2  13128.8
# 1983     15398.8  12964.2  13133.5  13271.7
# 1984     15596.3  13018.0  13409.3  13304.2
# 1985     15873.9  13366.5  13998.6  14045.1
# 1986     16650.3  13598.4  14183.2  14128.5
# 1987     16380.7  13512.8  14022.1  14231.8
# 1988     16737.0  14004.5  14165.5  14203.9
# 1989     16895.1  14248.2  14719.5  14855.8
# 1990     17361.6  14585.2  14873.5  14798.4
# 1991     17115.2  14284.9  14558.8  14914.3
# 1992     17342.3      NaN      NaN      NaN

# %%
quarterly_turnover.plot()

# %%
quarterly_turnover.boxplot()

# %% [markdown]
# # Task 1: Seasonality of Portugal Port

# %%
quart=pd.pivot_table(port,values='Pax',columns='Quarter',index='Year')
quart.head()
# Out:
# Quarter  Q1  Q2   Q3  Q4
# Year
# 2000     21  61  119  30
# 2001     16  71  124  33
# 2002     25  63  122  27
# 2003     23  77  149  39
# 2004     31  82  150  45

# %%
quart.plot()
plt.show()

# %%
quart.boxplot()

# %% [markdown]
# # Task 2: Seasonality of Petrol Consumption

# %%
petrol.head()
# Out:
#    Year Quarter  Consumption  TimeIndex
# 0  2001      Q1       14.978 2001-03-31
# 1  2001      Q2       11.099 2001-06-30
# 2  2001      Q3       10.057 2001-09-30
# 3  2001      Q4       10.454 2001-12-31
# 4  2002      Q1        9.295 2002-03-31

# %%
petroldata=pd.pivot_table(petrol,values='Consumption',columns='Quarter',index='Year')
petroldata.head()
# Out:
# Quarter        Q1        Q2        Q3        Q4
# Year
# 2001     14.97800  11.09900  10.05700  10.45400
# 2002      9.29500   7.95200   8.06300  10.93300
# 2003     12.27800  10.84700  10.71800  10.85900
# 2004      9.09425   5.67257   5.32862   5.51024
# 2005      7.08428   5.23772   6.36947   6.71848

# %%
petroldata.plot()

# %%
petroldata.boxplot()

# %% [markdown]
# # Visualization of Seasonality: Monthly Temperature

# %%
monthly_temp = pd.pivot_table(AirTemp, values = "AvgTemp", columns = "Month", index = "Year")
monthly_temp = monthly_temp[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
monthly_temp
# Out:
# Month   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# Year
# 1920   40.6  40.8  44.4  46.7  54.1  58.5  57.7  56.4  54.3  50.5  42.9  39.8
# 1921   44.2  39.8  45.1  47.0  54.1  58.7  66.3  59.9  57.0  54.2  39.7  42.8
# 1922   37.5  38.7  39.5  42.1  55.7  57.8  56.8  54.3  54.3  47.1  41.8  41.7
# 1923   41.8  40.1  42.9  45.8  49.2  52.7  64.2  59.6  54.4  49.2  36.6  37.6
# 1924   39.3  37.5  38.3  45.5  53.2  57.7  60.8  58.2  56.4  49.8  44.4  43.6
# 1925   40.0  40.5  40.8  45.1  53.8  59.4  63.5  61.0  53.0  50.0  38.1  36.3
# 1926   39.2  43.4  43.4  48.9  50.6  56.8  62.5  62.0  57.5  46.7  41.6  39.8
# 1927   39.4  38.5  45.3  47.1  51.7  55.0  60.4  60.5  54.7  50.3  42.3  35.2
# 1928   40.8  41.1  42.8  47.3  50.9  56.4  62.2  60.5  55.4  50.2  43.0  37.3
# 1929   34.8  31.3  41.0  43.9  53.1  56.9  62.5  60.3  59.8  49.2  42.9  41.9
# 1930   41.6  37.1  41.2  46.9  51.2  60.4  60.1  61.6  57.0  50.9  43.0  38.8
# ...

# %%
monthly_temp.plot()

# %%
monthly_temp.boxplot()

# %% [markdown]
# # Task 3: Seasonality of Champagne Sales

# %%
cham.head()
# Out:
#    Year Month  Sales  TimeIndex
# 0  1964   Jan   2815 1964-01-31
# 1  1964   Feb   2672 1964-02-29
# 2  1964   Mar   2755 1964-03-31
# 3  1964   Apr   2721 1964-04-30
# 4  1964   May   2946 1964-05-31

# %%
champagne=pd.pivot_table(cham,values='Sales',columns='Month',index='Year')
champagne = champagne[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
champagne.head()
# Out:
# Month     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug     Sep  \
# Year
# 1964   2815.0  2672.0  2755.0  2721.0  2946.0  3036.0  2282.0  2212.0  2922.0
# 1965   2541.0  2475.0  3031.0  3266.0  3776.0  3230.0  3028.0  1759.0  3595.0
# 1966   3113.0  3006.0  4047.0  3523.0  3937.0  3986.0  3260.0  1573.0  3528.0
# 1967   5375.0  3088.0  3718.0  4514.0  4520.0  4539.0  3663.0  1643.0  4739.0
# 1968   3633.0  4292.0  4154.0  4121.0  4647.0  4753.0  3965.0  1723.0  5048.0
#
# Month     Oct     Nov      Dec
# Year
# 1964   4301.0  5764.0   7312.0
# 1965   4474.0  6838.0   8357.0
# 1966   5211.0  7614.0   9254.0
# 1967   5428.0  8314.0  10651.0
# 1968   6922.0  9858.0  11331.0

# %%
champagne.plot()
plt.show()

# %%
champagne.boxplot()
plt.show()

# %% [markdown]
# # Task 4: Seasonality of Air Passengers

# %%
air.head()
# Out:
#   Year-Month  International Airlines Pax  TimeIndex
# 0    1949-01                         112 1949-01-31
# 1    1949-02                         118 1949-02-28
# 2    1949-03                         132 1949-03-31
# 3    1949-04                         129 1949-04-30
# 4    1949-05                         121 1949-05-31

# %%
airpassenger=pd.pivot_table(air,values='Pax',columns='Month',index='Year')
airpassenger = airpassenger[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
airpassenger.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-4f7d060d3442> in <module>()
# ----> 1 airpassenger=pd.pivot_table(air,values='Pax',columns='Month',index='Year')
#       2 airpassenger = airpassenger[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
#       3 airpassenger.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      59         for i in values:
#      60             if i not in data:
# ---> 61                 raise KeyError(i)
#      62
#      63         to_filter = []
#
# KeyError: 'Pax'

# %%
airpassenger.plot()
plt.show()

# %%
airpassenger.boxplot()
plt.show()

# %% [markdown]
# # Task 5: Seasonality of Tractor Sales

# %%
Tractor.head()

# %%
tractors=pd.pivot_table(Tractor,values='Tractor-Sales',columns='Month',index='Year')
tractors = tractors[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
tractors.head()

# %%
tractors.plot()
plt.show()

# %%
tractors.boxplot()
plt.show()

# %% [markdown]
# # Task 6: Seasonality of CO2 Emission

# %% [markdown]
# # Task 7: Seasonality of Retail Food Sales

# %% [markdown]
# # Task 8: Seasonality of MaunaLoa

# %%
mauna.head()

# %%
maunaloa=pd.pivot_table(mauna,values='CO2 ppm',columns='Month',index='Year')
maunaloa = maunaloa[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
maunaloa.head()

# %%
maunaloa.plot()
plt.show()

# %%
maunaloa.boxplot()
plt.show()

# %% [markdown]
# # Seasonal Decomposition

# %%
import statsmodels.api as sm

# %%
decompTurnover = sm.tsa.seasonal_decompose(Turnover.Turnover, model="additive", freq=4)
decompTurnover.plot()
plt.show()

# %%
trend = decompTurnover.trend
seasonal = decompTurnover.seasonal
residual = decompTurnover.resid

# %%
trend.head(12)

# %%
seasonal.head(12)

# %%
residual.head(12)               # difference between seasonal and trend

# %%
decompTurnover = sm.tsa.seasonal_decompose(air['International Airlines Pax'], model="multiplicative", freq=4)
decompTurnover.plot()
plt.show()

# %%
decompTurnover = sm.tsa.seasonal_decompose(mauna['CO2 ppm'], model="additive", freq=4)
decompTurnover.plot()
plt.show()

# %%
trend = decompTurnover.trend
seasonal = decompTurnover.seasonal
residual = decompTurnover.resid

# %%
trend.head(12)
# Out:
# 0           NaN
# 1           NaN
# 2     320.99625
# 3     321.55125
# 4     321.79750
# 5     321.43875
# 6     320.48875
# 7     319.37250
# 8     318.51625
# 9     318.26750
# 10    318.56750
# 11    319.28375
# Name: CO2 ppm, dtype: float64

# %%
seasonal.head(12)
# Out:
# 0    -0.057128
# 1    -0.097819
# 2     0.070824
# 3     0.084122
# 4    -0.057128
# 5    -0.097819
# 6     0.070824
# 7     0.084122
# 8    -0.057128
# 9    -0.097819
# 10    0.070824
# 11    0.084122
# Name: CO2 ppm, dtype: float64

# %%
residual.head(12)
# Out:
# 0          NaN
# 1          NaN
# 2    -0.247074
# 3     0.424628
# 4     0.429628
# 5     0.609069
# 6     0.640426
# 7    -0.646622
# 8    -0.639122
# 9    -0.799681
# 10    0.291676
# 11   -0.277872
# Name: CO2 ppm, dtype: float64

# %%
sum(seasonal)
# Out:
# -1.3183898417423734e-15

# %%
decompTurnover = sm.tsa.seasonal_decompose(air['International Airlines Pax'], model="multiplicative", freq=4)
decompTurnover.plot()
plt.show()
trend = decompTurnover.trend
seasonal = decompTurnover.seasonal
residual = decompTurnover.resid

# %%
trend.head(12)
# Out:
# 0         NaN
# 1         NaN
# 2     123.875
# 3     127.125
# 4     131.250
# 5     135.625
# 6     139.875
# 7     139.750
# 8     132.250
# 9     123.000
# 10    116.625
# 11    114.875
# Name: International Airlines Pax, dtype: float64

# %%
seasonal.head(12)
# Out:
# 0     0.984384
# 1     0.971888
# 2     1.011907
# 3     1.031822
# 4     0.984384
# 5     0.971888
# 6     1.011907
# 7     1.031822
# 8     0.984384
# 9     0.971888
# 10    1.011907
# 11    1.031822
# Name: International Airlines Pax, dtype: float64

# %%
residual.head(12) # Yt / seasonal * trend
# Out:
# 0          NaN
# 1          NaN
# 2     1.053052
# 3     0.983454
# 4     0.936530
# 5     1.024184
# 6     1.045638
# 7     1.026373
# 8     1.044669
# 9     0.995465
# 10    0.881254
# 11    0.995524
# Name: International Airlines Pax, dtype: float64

# %%
sum(seasonal)
# Out:
# 144.0000000000002

# %%
decompTurnover = sm.tsa.seasonal_decompose(cham.Sales, model="additive", freq=4)
decompTurnover.plot()
plt.show()
trend = decompTurnover.trend
seasonal = decompTurnover.seasonal
residual = decompTurnover.resid

# %%
trend.head(12)
# Out:
# 0          NaN
# 1          NaN
# 2     2757.125
# 3     2819.000
# 4     2805.375
# 5     2682.625
# 6     2616.000
# 7     2771.125
# 8     3364.500
# 9     4437.250
# 10    5027.125
# 11    4751.250
# Name: Sales, dtype: float64

# %%
seasonal.head(12)
# Out:
# 0    -714.787692
# 1    -384.962692
# 2     467.783077
# 3     631.967308
# 4    -714.787692
# 5    -384.962692
# 6     467.783077
# 7     631.967308
# 8    -714.787692
# 9    -384.962692
# 10    467.783077
# 11    631.967308
# Name: Sales, dtype: float64

# %%
residual.head(12)
# Out:
# 0             NaN
# 1             NaN
# 2     -469.908077
# 3     -729.967308
# 4      855.412692
# 5      738.337692
# 6     -801.783077
# 7    -1191.092308
# 8      272.287692
# 9      248.712692
# 10     269.091923
# 11    1928.782692
# Name: Sales, dtype: float64

# %% [markdown]
# # Split Data in Training and Test

# %%
Petrol = pd.read_csv('Petrol.csv')
Petrol.head()
# Out:
#    Year Quarter  Consumption
# 0  2001      Q1       14.978
# 1  2001      Q2       11.099
# 2  2001      Q3       10.057
# 3  2001      Q4       10.454
# 4  2002      Q1        9.295

# %%
date_rng = pd.date_range(start='1/1/2001', end='30/9/2013', freq='Q')
date_rng
Petrol['TimeIndex'] = pd.DataFrame(date_rng, columns=['Quarter'])
Petrol.head()
plt.plot(Petrol.TimeIndex, Petrol.Consumption)
pyplot.show()

# %%
#Creating train and test set 
train=Petrol[0:int(len(Petrol)*0.7)] 
test=Petrol[int(len(Petrol)*0.7):]

# %%
type(train)
train.head()
# Out:
#    Year Quarter  Consumption  TimeIndex
# 0  2001      Q1       14.978 2001-03-31
# 1  2001      Q2       11.099 2001-06-30
# 2  2001      Q3       10.057 2001-09-30
# 3  2001      Q4       10.454 2001-12-31
# 4  2002      Q1        9.295 2002-03-31

# %%
plt.plot(train.Consumption)
plt.plot(test.Consumption)
pyplot.show()

# %%
train.Consumption.plot()
test.Consumption.plot()

# %% [markdown]
# # Simple Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
# create class
model = SimpleExpSmoothing(np.asarray(train['Consumption']))

# %%
# fit model
model99_fit = model.fit(smoothing_level=0.99,optimized=False)
model5_fit = model.fit(smoothing_level=0.5,optimized=False)
model1_fit = model.fit(smoothing_level=0.1,optimized=False)

# %%
fcst_SES = test.copy()

# %%
fcst_SES['SES99'] = model99_fit.forecast(len(test['Consumption']))
fcst_SES['SES5'] = model5_fit.forecast(len(test['Consumption']))
fcst_SES['SES1'] = model1_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_SES['SES99'], label='SES99')
plt.plot(fcst_SES['SES5'], label='aSES5')
plt.plot(fcst_SES['SES1'], label='SES1')
plt.legend(loc='best')

# %%
fcst_SES['SES99']
# Out:
# 35    1.986998
# 36    1.986998
# 37    1.986998
# 38    1.986998
# 39    1.986998
# 40    1.986998
# 41    1.986998
# 42    1.986998
# 43    1.986998
# 44    1.986998
# 45    1.986998
# 46    1.986998
# 47    1.986998
# 48    1.986998
# 49    1.986998
# 50    1.986998
# Name: SES99, dtype: float64

# %%
#
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(test['Consumption'],fcst_SES['SES99'])
# Out:
# 94.50460480680182

# %%
rmse = sqrt(mean_squared_error(test['Consumption'],fcst_SES['SES99']))
rmse
# Out:
# 0.9437879263674692

# %%
model_opt_fit = model.fit()

# %%
model_opt_fit.model.params
# Out:
# {'smoothing_level': 1.0,
#  'smoothing_slope': nan,
#  'smoothing_seasonal': nan,
#  'damping_slope': nan,
#  'initial_level': 14.978,
#  'initial_slope': nan,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(model1_fit.fittedvalues, label='FIT 1')
plt.plot(model5_fit.fittedvalues, label='FIT 5')
plt.plot(model99_fit.fittedvalues, label='FIT 99')

plt.legend(loc='best')

# %% [markdown]
# # Double Exponential (Holt)

# %%
model = Holt(np.asarray(train['Consumption']))
model31_fit = model.fit(smoothing_level = 0.3,smoothing_slope = 0.1,optimized=False)

# %%
model31_fit = model.fit(smoothing_level = 0.3,smoothing_slope = 0.1,optimized=False)

# %%
fcst_Holt = test.copy()

# %%
fcst_Holt['Holt31'] = model31_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_Holt['Holt31'], label='Holt31')
plt.legend(loc='best')

# %%
modelopt_fit = model.fit()

# %%
fcst_Holt['Opt'] = modelopt_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_Holt['Opt'], label='HoltOpt')
plt.legend(loc='best')

# %%
modelopt_fit.model.params
# Out:
# {'smoothing_level': 1.0,
#  'smoothing_slope': 0.019969001307085045,
#  'smoothing_seasonal': nan,
#  'damping_slope': nan,
#  'initial_level': 15.127123152052901,
#  'initial_slope': 0.0,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %% [markdown]
# # US GDP

# %%
USGDP.head()
# Out:
#    Year    GDP  TimeIndex
# 0  1929  821.8 1929-12-31
# 1  1930  748.9 1930-12-31
# 2  1931  691.3 1931-12-31
# 3  1932  599.7 1932-12-31
# 4  1933  587.1 1933-12-31

# %%
#Creating train and test set 
train=USGDP[0:int(len(USGDP)*0.7)] 
test=USGDP[int(len(USGDP)*0.7):]

# %%
train.head()
# Out:
#    Year    GDP  TimeIndex
# 0  1929  821.8 1929-12-31
# 1  1930  748.9 1930-12-31
# 2  1931  691.3 1931-12-31
# 3  1932  599.7 1932-12-31
# 4  1933  587.1 1933-12-31

# %%
plt.plot(train.GDP)
plt.plot(test.GDP)
plt.show()

# %%
model = Holt(np.asarray(train['GDP']))
model31_fit = model.fit()
fcst_Holt['Holt31'] = model31_fit.forecast(len(test['GDP']))
plt.figure(figsize=(16,8))
plt.plot(train['GDP'], label='Train')
plt.plot(test['GDP'], label='Test')
plt.plot(fcst_Holt['Holt31'], label='Holt31')
plt.legend(loc='best')

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(test['GDP'],fcst_Holt['Holt31'])
# Out:
# 18.71894662616716

# %%
rmse = sqrt(mean_squared_error(test['GDP'],fcst_Holt['Holt31']))
rmse
# Out:
# 869.9266656332985

# %%
model = Holt(np.asarray(train['GDP']))
model31_fit = model.fit(smoothing_level = 0.3,smoothing_slope = 0.1,optimized=False)
fcst_Holt = test.copy()
fcst_Holt['Holt31'] = model31_fit.forecast(len(test['GDP']))
plt.figure(figsize=(16,8))
plt.plot(train['GDP'], label='Train')
plt.plot(test['GDP'], label='Test')
plt.plot(fcst_Holt['Holt31'], label='Holt31')
plt.legend(loc='best')

# %%
mean_absolute_percentage_error(test['GDP'],fcst_Holt['Holt31'])
# Out:
# 2.4481867716445036

# %%
rmse = sqrt(mean_squared_error(test['GDP'],fcst_Holt['Holt31']))
rmse
# Out:
# 126.83150745284067

# %%
USGDP.tail()
# Out:
#     Year     GDP  TimeIndex
# 58  1987  4718.6 1987-12-31
# 59  1988  4784.6 1988-12-31
# 60  1989  4739.2 1989-12-31
# 61  1990  4822.3 1990-12-31
# 62  1991  4835.0 1991-12-31

# %%
model = Holt(np.asarray(USGDP['GDP']))
model31_fit = model.fit(smoothing_level = 0.3,smoothing_slope = 0.1,optimized=False)

# %%
model31_fit.forecast(5)
# Out:
# array([5022.87314127, 5115.77583543, 5208.67852959, 5301.58122374,
#        5394.4839179 ])

# %% [markdown]
# # Triple Exponential

# %%
AirPax = pd.read_csv('AirPax.csv')
AirPax.head()
date_rng = pd.date_range(start='1/1/1949', end='31/12/1960', freq='M')
date_rng
AirPax['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
AirPax.head()
plt.plot(AirPax.TimeIndex, AirPax.Pax)
plt.legend(loc='best')
pyplot.show()

# %%
AirPax.head()
# Out:
#    Year Month  Pax  TimeIndex
# 0  1949   Jan  112 1949-01-31
# 1  1949   Feb  118 1949-02-28
# 2  1949   Mar  132 1949-03-31
# 3  1949   Apr  129 1949-04-30
# 4  1949   May  121 1949-05-31

# %%
monthly_airpax = pd.pivot_table(AirPax, values = "Pax", columns = "Month", index = "Year")
monthly_airpax = monthly_airpax[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
monthly_airpax
# Out:
# Month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# Year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
plt.figure(figsize=(20,8))
monthly_airpax.plot()

# %%
decompTurnover = sm.tsa.seasonal_decompose(AirPax.Pax, model="additive", freq=4)
decompTurnover.plot()
plt.show()
trend = decompTurnover.trend
seasonal = decompTurnover.seasonal
residual = decompTurnover.resid

# %%
train=AirPax[0:120] 
test=AirPax[120:]

# %%
#model1_fit=ExponentialSmoothing(np.asarray(train['Pax']), seasonal_periods=12 ,seasonal='add').fit(optimized=True)

# %%
model1_fit=ExponentialSmoothing(np.asarray(train['Pax']),seasonal_periods=12,trend='add',seasonal='add').fit(optimized=True)
model2_fit=ExponentialSmoothing(np.asarray(train['Pax']),seasonal_periods=12,trend='add',seasonal='mul').fit(optimized=True)

fcst_HoltWinters = test.copy()
fcst_HoltWinters['HoltWinter-Add'] = model1_fit.forecast(len(test['Pax']))
fcst_HoltWinters['HoltWinter-Mul'] = model2_fit.forecast(len(test['Pax']))

plt.plot(train['Pax'],label='Train')
plt.plot(test['Pax'],label='Test')
plt.plot(fcst_HoltWinters['HoltWinter-Add'],label='Holt Winters - Add')
plt.plot(fcst_HoltWinters['HoltWinter-Mul'],label='Holt Winters - Mul')

plt.legend()
plt.show()

# %%
model1_fit.params
# Out:
# {'smoothing_level': 0.26315789260838723,
#  'smoothing_slope': 0.05141838739813674,
#  'smoothing_seasonal': 0.736842103134703,
#  'damping_slope': nan,
#  'initial_level': 211.39035283742217,
#  'initial_slope': 1.7962247335415404,
#  'initial_seasons': array([-100.1395798 ,  -94.16165954,  -80.25990726,  -83.40455348,
#          -91.44797501,  -77.43423911,  -64.47532102,  -64.61801335,
#          -76.73545611,  -93.82369122, -108.75465114,  -94.55491878]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
mean_absolute_percentage_error(test['Pax'],fcst_HoltWinters['HoltWinter-Add'])
# Out:
# 6.424691230905577

# %%
mean_absolute_percentage_error(test['Pax'],fcst_HoltWinters['HoltWinter-Mul'] )
# Out:
# 7.541714573889495

# %%
AirPax['Logpax']=np.log10(AirPax['Pax'])

# %%
train=AirPax[0:120] 
test=AirPax[120:]

model1_fit=ExponentialSmoothing(np.asarray(train['Logpax']),seasonal_periods=12,trend='add',seasonal='add').fit(optimized=True)
model2_fit=ExponentialSmoothing(np.asarray(train['Logpax']),seasonal_periods=12,trend='add',seasonal='mul').fit(optimized=True)

fcst_HoltWinters = test.copy()
fcst_HoltWinters['HoltWinter-Add'] = model1_fit.forecast(len(test))
fcst_HoltWinters['HoltWinter-Mul'] = model2_fit.forecast(len(test))

plt.plot(train['Logpax'],label='Train')
plt.plot(test['Logpax'],label='Test')
plt.plot(fcst_HoltWinters['HoltWinter-Add'],label='Holt Winters - Add')
plt.plot(fcst_HoltWinters['HoltWinter-Mul'],label='Holt Winters - Mul')

plt.legend()
plt.show()

# %% [markdown]
# # Champagne

# %%
cham.head()
# Out:
#    Year Month  Sales  TimeIndex
# 0  1964   Jan   2815 1964-01-31
# 1  1964   Feb   2672 1964-02-29
# 2  1964   Mar   2755 1964-03-31
# 3  1964   Apr   2721 1964-04-30
# 4  1964   May   2946 1964-05-31

# %%
cham1=pd.pivot_table(cham,values='Sales',columns='Month',index='Year')
cham1= cham1[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
cham1.head()
# Out:
# Month     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug     Sep  \
# Year
# 1964   2815.0  2672.0  2755.0  2721.0  2946.0  3036.0  2282.0  2212.0  2922.0
# 1965   2541.0  2475.0  3031.0  3266.0  3776.0  3230.0  3028.0  1759.0  3595.0
# 1966   3113.0  3006.0  4047.0  3523.0  3937.0  3986.0  3260.0  1573.0  3528.0
# 1967   5375.0  3088.0  3718.0  4514.0  4520.0  4539.0  3663.0  1643.0  4739.0
# 1968   3633.0  4292.0  4154.0  4121.0  4647.0  4753.0  3965.0  1723.0  5048.0
#
# Month     Oct     Nov      Dec
# Year
# 1964   4301.0  5764.0   7312.0
# 1965   4474.0  6838.0   8357.0
# 1966   5211.0  7614.0   9254.0
# 1967   5428.0  8314.0  10651.0
# 1968   6922.0  9858.0  11331.0

# %%
cham1.plot()
plt.show()

# %%
decompTurnover = sm.tsa.seasonal_decompose(cham.Sales, model="additive", freq=4)
decompTurnover.plot()
plt.show()
trend = decompTurnover.trend
seasonal = decompTurnover.seasonal
residual = decompTurnover.resid

# %%
train=cham[0:int(len(cham)*0.7)] 
test=cham[int(len(cham)*0.7):]

# %%
plt.plot(train.Sales)
plt.plot(test.Sales)
plt.show()

# %%
model1_fit=ExponentialSmoothing(np.asarray(train['Sales']), seasonal_periods=12 ,seasonal='add').fit(optimized=True)

# %%
fcst_HoltW = test.copy()
fcst_HoltW['HoltW'] = model1_fit.forecast(len(test['Sales']))
plt.figure(figsize=(16,8))
plt.plot(train['Sales'], label='Train')
plt.plot(test['Sales'], label='Test')
plt.plot(fcst_HoltW['HoltW'], label='HoltWinters')
plt.legend(loc='best')
plt.show()

# %%
mean_absolute_percentage_error(test['Sales'],fcst_HoltW['HoltW'])
# Out:
# 15.005690413530678

# %%
model2_fit = ExponentialSmoothing(np.asarray(train['Sales']),  seasonal_periods=12, trend='add',seasonal='mul').fit(smoothing_slope = 0.2, smoothing_seasonal=0.5, smoothing_level = 0.2, optimized=False)

# %%
fcst_HoltW['HoltWM'] = model2_fit.forecast(len(test['Sales']))
plt.figure(figsize=(16,8))
plt.plot(train['Sales'], label='Train')
plt.plot(test['Sales'], label='Test')
plt.plot(fcst_HoltW['HoltW'], label='HoltWinters Additive')
plt.plot(fcst_HoltW['HoltWM'], label='HoltWinters Multiplicative')
plt.legend(loc='best')

# %%
mean_absolute_percentage_error(test['Sales'],fcst_HoltW['HoltWM'])
# Out:
# 13.43044071013406

# %%
model2= ExponentialSmoothing(np.asarray(train['Sales']),  seasonal_periods=12, trend='add',seasonal='mul').fit(smoothing_slope = 0.2, smoothing_seasonal=0.5, smoothing_level = 0.2, optimized=False)

# %%
model2.forecast(24)
# Out:
# array([ 4040.22113885,  4420.79603685,  4347.01284357,  4902.50215934,
#         4732.98328653,  3719.72734443,  1856.82098748,  5157.80561558,
#         6681.52072713,  9921.16223875, 12001.19900558,  4094.92755838,
#         3943.25138588,  4314.47942459,  4242.26072441,  4784.1264261 ,
#         4618.47033411,  3629.54795999,  1811.71393114,  5032.25481361,
#         6518.54921392,  9678.67852127, 11707.27834116,  3994.4338277 ])

# %%
pred = cham.copy()

# %%
pred['HoltW'] = model1_fit.forecast(len(cham['Sales']))

# %%
pred.tail()
# Out:
#      Year Month  Sales  TimeIndex        HoltW
# 100  1972   May   4618 1972-05-31  4838.507500
# 101  1972   Jun   5312 1972-06-30  3760.129654
# 102  1972   Jul   4298 1972-07-31  2042.854723
# 103  1972   Aug   1413 1972-08-31  5434.135315
# 104  1972   Sep   5877 1972-09-30  7086.252655

# %%
plt.plot(cham['Sales'])
plt.plot(model2.forecast(24))
