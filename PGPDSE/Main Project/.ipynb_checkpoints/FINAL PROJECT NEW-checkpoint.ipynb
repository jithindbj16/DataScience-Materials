# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Try these things to understand data in more details
#
# How many articles are there for Palestine and Microsoft each?
#
# What is hour of publication for each article.
#
# How many articles are there, where status of all social media platform is greater than zero? How many Microsoft and how many are Palestine.
#
# How sentimentTitle and Sentiment headings are spread?
#
# Try to summarize to article and headlines. (We'll discuss this in details in this week)
#
# For each topic (microsoft and palestine), how many news article are present in their individual social media platform file.
#
# How are the data spread in separate file for each social media platform file for articles with Facebook/Googleplus/Linkedin values are -1.
#
# How are the data spread in separate file for each social media platform file for articles with Facebook/Googleplus/Linkedin values are -1.
#
# What meaning is coming out of Facebook/Googleplus/Linkedin columns with columns -1 and 0

# %%
#READING THE DATASET
news=pd.read_csv('News_Final.csv',encoding='latin-1')

# %%
news.head()
# Out:
#     IDLink                                              Title  \
# 0  99248.0   Obama Lays Wreath at Arlington National Cemetery
# 1  10423.0        A Look at the Health of the Chinese Economy
# 2  18828.0   Nouriel Roubini: Global Economy Not Back to 2008
# 3  27788.0                          Finland GDP Expands In Q4
# 4  27789.0  Tourism, govt spending buoys Thai economy in J...
#
#                                             Headline  \
# 0  Obama Lays Wreath at Arlington National Cemete...
# 1  Tim Haywood, investment director business-unit...
# 2  Nouriel Roubini, NYU professor and chairman at...
# 3  Finland's economy expanded marginally in the t...
# 4  Tourism and public spending continued to boost...
#
#                                      Source    Topic          PublishDate  \
# 0                                 USA TODAY    obama  2002-04-02 00:00:00
# 1                                 Bloomberg  economy  2008-09-20 00:00:00
# 2                                 Bloomberg  economy  2012-01-28 00:00:00
# 3                                  RTT News  economy  2015-03-01 00:06:00
# 4  The Nation - Thailand&#39;s English news  economy  2015-03-01 00:11:00
#
#    SentimentTitle  SentimentHeadline  Facebook  GooglePlus  LinkedIn
# 0        0.000000          -0.053300        -1          -1        -1
# 1        0.208333          -0.156386        -1          -1        -1
# 2       -0.425210           0.139754        -1          -1        -1
# 3        0.000000           0.026064        -1          -1        -1
# 4        0.000000           0.141084        -1          -1        -1

# %% [markdown]
# # column description

# %% [raw]
# VARIABLES OF NEWS DATA
# #
# # IDLink (numeric): Unique identifier of news items
# # Title (string): Title of the news item according to the official media sources
# # Headline (string): Headline of the news item according to the official media sources
# # Source (string): Original news outlet that published the news item
# # Topic (string): Query topic used to obtain the items in the official media sources
# # PublishDate (timestamp): Date and time of the news items' publication
# # SentimentTitle (numeric): Sentiment score of the text in the news items' title
# # SentimentHeadline (numeric): Sentiment score of the text in the news items' headline
# # Facebook (numeric): Final value of the news items' popularity according to the social media source Facebook
# # GooglePlus (numeric): Final value of the news items' popularity according to the social media source Google+
# # LinkedIn (numeric): Final value of the news items' popularity according to the social media source LinkedIn

# %%
# as our objective is to compare the popularity of palestine and microsoft we are taking the rows  of palestine and microsoft and creating a new dataframe for it
palestine=news[news['Topic']=='palestine']

# %%
microsoft=news[news['Topic']=='microsoft']

# %%
combined=pd.concat([palestine,microsoft],axis=0)

# %%
#as we can see there are null values in the headline and the source column
combined.isnull().sum()
# Out:
# IDLink                 0
# Title                  0
# Headline               4
# Source               239
# Topic                  0
# PublishDate            0
# SentimentTitle         0
# SentimentHeadline      0
# Facebook               0
# GooglePlus             0
# LinkedIn               0
# dtype: int64

# %%
combined=combined.dropna()

# %%
combined.shape
# Out:
# (30458, 11)

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30458 entries, 8 to 93238
# Data columns (total 11 columns):
# IDLink               30458 non-null float64
# Title                30458 non-null object
# Headline             30458 non-null object
# Source               30458 non-null object
# Topic                30458 non-null object
# PublishDate          30458 non-null object
# SentimentTitle       30458 non-null float64
# SentimentHeadline    30458 non-null float64
# Facebook             30458 non-null int64
# GooglePlus           30458 non-null int64
# LinkedIn             30458 non-null int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 2.8+ MB

# %% [markdown]
# How many articles are there for Palestine and Microsoft each?

# %%
combined['Topic'].value_counts()
# Out:
# microsoft    21851
# palestine     8607
# Name: Topic, dtype: int64

# %%
#WE ARE CONVERTING THE OBJECT TYPE OF DATE TO DATETIME
combined['Date'] = pd.to_datetime(combined['PublishDate'])

# %% [markdown]
# What is hour of publication for each article.

# %%
def hr_func(ts):
    return ts.hour

combined['time_hour'] = combined['Date'].apply(hr_func)

# %%
combined.head(10)
# Out:
#       IDLink                                              Title  \
# 8    80771.0  Fire claims more than 100-year-old barn in Han...
# 140  70308.0  The British must formally ÂÂÂ and swiftly Â...
# 141  69864.0  Palestine flag to fly at UN headquarters after...
# 142  69866.0  The First-Ever Raising of Palestine's Flag at ...
# 145  69978.0                     Palestine: The Psychotic Stage
# 146  70211.0  India offers $5 mn budgetary support to Palestine
# 165  70210.0  Free Palestine demonstrators protest outside I...
# 193  62031.0  Palestine v Saudi Arabia goes ahead in Al-Ram ...
# 194  62047.0  Israeli Palestinian conflict: Two viewpoints; ...
# 195  62065.0  A Beginner's Guide To The Recent Outbreak Of F...
#
#                                               Headline               Source  \
# 8    A Hancock County man lost a barn early Monday ...    WTHR Indianapolis
# 140  Forced evictions of Palestinian farmers from t...         The Guardian
# 141  Palestine's flag will fly at UN headquarters a...         The Guardian
# 142  Tomorrow, the Palestinian flag will be raised ...      Huffington Post
# 145  As in this headline: """Palestinian Killed As ...  Wall Street Journal
# 146  President Pranab Mukherjee on Monday held talk...            The Hindu
# 165  Layla White, of London Palestine Action which ...           Daily Mail
# 193  Palestine will host Saudi Arabia in a World Cu...            SkySports
# 194  Hebron, West Bank (CNN) The armed Israeli poli...                  CNN
# 195  Understanding why there is so much tension and...          New Matilda
#
#          Topic          PublishDate  SentimentTitle  SentimentHeadline  \
# 8    palestine  2015-03-01 01:20:00       -0.173925          -0.050185
# 140  palestine  2015-09-09 00:00:00        0.000000           0.104170
# 141  palestine  2015-09-10 00:00:00        0.024156          -0.355276
# 142  palestine  2015-09-29 00:00:00        0.081857           0.194754
# 145  palestine  2015-10-12 00:00:00        0.000000          -0.053572
# 146  palestine  2015-10-12 00:00:00       -0.188982           0.028677
# 165  palestine  2015-10-17 00:00:00       -0.114583           0.034793
# 193  palestine  2015-10-21 00:00:00        0.072169          -0.122176
# 194  palestine  2015-10-21 00:00:00       -0.099437          -0.043015
# 195  palestine  2015-10-21 00:00:00       -0.037689          -0.103041
#
#      Facebook  GooglePlus  LinkedIn                Date  time_hour
# 8          -1          -1        -1 2015-03-01 01:20:00          1
# 140        -1          -1        -1 2015-09-09 00:00:00          0
# 141        -1          -1        -1 2015-09-10 00:00:00          0
# 142        -1          -1        -1 2015-09-29 00:00:00          0
# 145        -1          -1        -1 2015-10-12 00:00:00          0
# 146        -1          -1        -1 2015-10-12 00:00:00          0
# 165        -1          -1        -1 2015-10-17 00:00:00          0
# 193        -1          -1        -1 2015-10-21 00:00:00          0
# 194        -1          -1        -1 2015-10-21 00:00:00          0
# 195        -1          -1        -1 2015-10-21 00:00:00          0

# %% [raw]
# How many articles are there, where status of all social media platform is greater than zero? How many Microsoft and how many are Palestine.

# %%
articlesg0=combined.loc[((combined.Facebook > 0) & (combined.LinkedIn >0) &(combined.GooglePlus > 0)),:]

# %%
articlesg0
# Out:
#         IDLink                                              Title  \
# 3441   61979.0  Israel to Sweden: Don't Make the Paris Attacks...
# 3445   61985.0                           Is Palestine the answer?
# 3886   62001.0  Israel Divides the Jews ÂÂÂ An Analysis by ...
# 4170   62516.0  5 Killed in Tel Aviv and West Bank by Palestin...
# 4189   61974.0    Israel is finally allowing Palestine to have 3G
# 4381   62434.0  ADL: American terror victim perished on 'blood...
# 4484   62476.0  Development in Palestine: Destined to fail bef...
# 4504   62496.0   TÂÂhe Child Ahmed Manasrah, Our Iconic Torture
# 4560   62537.0  Wall Street Journal Publishes Israel's Leading...
# 4822   62714.0     Israel closes down second Hebron radio station
# 4852   62810.0  University of Texas Professor Compares Palesti...
# 5043   62872.0  Palestinian startup to compete in Seedstars Wo...
# 5067   62937.0  How to fight intolerance with culture: A Pales...
# 5243   62986.0  Palestine-Israel Conflict Enflames Passion on ...
# 5253   62988.0  Why is Palestine absent from debate about camp...
# 6083   63431.0  US Congresswoman Introduces Bill to Stop ÂÂÂ...
# 6285   63447.0  Violence, Moral Equivalence, and the End of a ...
# 6752   63699.0  Co-op Bank closes Palestine Solidarity Campaig...
# 6919   63778.0  SodaStream on New Zealand shelves angers Pales...
# 6928   63833.0  Asia Pacific Screen Awards: Apichatpong Weeras...
# 7174   63924.0        From Pol Pot to ISIS: The blood never dried
# 7215   63938.0  Israel To Coordinate With Google, YouTube, To ...
# 7262   64011.0  Pro-BDS group uses Israeli platform Wix to bui...
# 7637   64139.0  Report: PM's brother-in-law says Netanyahu 've...
# 7655   64151.0  Bangladesh reiterates supports for independent...
# 7664   64161.0  UAE hospital gives Palestinian burn victim new...
# 7674   64167.0  November 29: International Day of Solidarity w...
# 7689   64210.0  Israel To Coordinate With Google, YouTube, To ...
# 7729   64216.0      It looks bad for Corbyn as UK strains for war
# 7749   64232.0                 GITR Palestine announces champions
# ...        ...                                                ...
# 86981  57872.0  Microsoft kicks off campaign touting battery s...
# 87003  57904.0  Microsoft disses Chrome's atrocious battery li...
# 87004  57905.0  Microsoft Working Towards Wider Adoption Of Bl...
# 87005  57797.0  Microsoft UK's tax bill challenged... by the S...
# 87026  57816.0  Windows 10-Powered Microsoft Lumia 550 Now Jus...
# 87045  57835.0             Microsoft Gets Baked in Cannabis Cloud
# 87053  57843.0  Brexit: BT, Virgin Media, HPE, IBM and Microso...
# 87078  57844.0  GoDaddy Goes Professional With Microsoft Offic...
# 87090  57880.0  Wonder what it's like to work for the best com...
# 87105  57866.0  Surface Pro 4 Sale: Microsoft Offers $50 To $1...
# 87118  57867.0  BadTunnel: Critical vulnerability affects ever...
# 87124  57865.0  Microsoft shows how bad Chrome is for your lap...
# 87158  57896.0  Tech vs Brexit: Bosses at Microsoft, IBM, SAP,...
# 87167  57903.0  Microsoft cancels Remain speech after death of...
# 87174  57892.0  Microsoft Removes Bloatware From Windows 10, A...
# 87182  57908.0  DFC: Microsoft has killed the Xbox One Slim ri...
# 87184  57909.0  How Microsoft Partners Are Putting IoT into Ac...
# 87196  57981.0  SEJ Wrap-Up: Microsoft Buys LinkedIn - Find Ou...
# 87207  57926.0  Why Microsoft cofounder Paul Allen is building...
# 87208  57916.0  Microsoft adding more teacher-focused Office 3...
# 87213  57942.0  Chrome's battery life is terrible, and this Mi...
# 87217  57924.0  Microsoft Says Google Chrome Browser Is Burnin...
# 87224  57933.0  With Xbox And Play Anywhere, Microsoft Wants t...
# 87250  57953.0  Microsoft, Amazon, other tech giants join figh...
# 87285  57976.0          Microsoft has had enough of OEM bloatware
# 87288  57980.0  Microsoft starts sending out invites for HoloL...
# 87900  58450.0  Microsoft Launches NFC Payments For Windows 10...
# 87999  58437.0  Microsoft announces new data protection tool t...
# 88030  58442.0  Microsoft Wallet Brings Tap-to-Pay to Windows ...
# 88036  58448.0  Microsoft updates Windows Maps as Here set to ...
#
#                                                 Headline  \
# 3441   But Swedish authorities didn't seem too concer...
# 3445   Margot Wallstr""m told television network SVT2...
# 3886   Ahad Ha-am (the pen name of the famous Jewish ...
# 4170   JERUSALEM """ Five people were killed on Thurs...
# 4189   One feature of Israel's control over Palestine...
# 4381   A Palestinian who drove from the direction of ...
# 4484   Susiya village in the south Hebron hills of Pa...
# 4504   The child Manasrah was an iconic sample of the...
# 4560   Yesterday, Israeli-Palestinian Knesset member ...
# 4822   Israeli forces raided and shut down a Palestin...
# 4852   The Palestinian Solidarity Committee have reta...
# 5043   The Ramallah-based real-estate analytics start...
# 5067   More than two decades later, in 2011, the Pale...
# 5243   On November 13, members of UT Austin's Palesti...
# 5253   Students take part in a March 2014 rally again...
# 6083   (ZeroHedge) """Last month, US Congresswoman Tu...
# 6285   Violence, Moral Equivalence, and the End of a ...
# 6752   The Palestine Solidarity Campaign (PSC) has fi...
# 6919   The internationally known Israeli product Soda...
# 6928   Palestine's 'The Idol' was another major winne...
# 7174   There should be an immediate cessation of all ...
# 7215   The Israeli Deputy Foreign Minister, Member of...
# 7262   Students for Justice in Palestine at U. of Den...
# 7637   The two-state solution - an independent Palest...
# 7655   Dhaka """ Bangladesh on Saturday reiterated su...
# 7664   Basic skin grafts were completed on the Palest...
# 6928  2015-11-26 03:28:00          3
# 7174  2015-11-26 20:45:42         20
# 7215  2015-11-27 00:39:42          0
# 7262  2015-11-27 05:44:44          5
# 7637  2015-11-28 14:56:46         14
# 7655  2015-11-28 16:41:42         16
# 7664  2015-11-28 17:13:46         17
# 7674  2015-11-28 18:22:43         18
# 7689  2015-11-28 19:44:41         19
# 7729  2015-11-28 23:52:46         23
# 7749  2015-11-29 02:19:42          2
# ...                   ...        ...
# 86981 2016-06-20 06:21:00          6
# 87003 2016-06-20 08:31:00          8
# 87004 2016-06-20 08:31:00          8
# 87005 2016-06-20 08:31:11          8
# 87026 2016-06-20 10:37:11         10
# 87045 2016-06-20 11:05:12         11
# 87053 2016-06-20 11:20:13         11
# 87078 2016-06-20 12:12:13         12
# 87090 2016-06-20 12:20:10         12
# 87105 2016-06-20 13:20:13         13
# 87118 2016-06-20 13:52:14         13
# 87124 2016-06-20 14:01:13         14
# 87158 2016-06-20 15:20:12         15
# 87167 2016-06-20 15:40:12         15
# 87174 2016-06-20 15:46:12         15
# 87182 2016-06-20 16:00:11         16
# 87184 2016-06-20 16:00:12         16
# 87196 2016-06-20 16:40:12         16
# 87207 2016-06-20 17:04:14         17
# 87208 2016-06-20 17:05:13         17
# 87213 2016-06-20 17:20:12         17
# 87217 2016-06-20 17:30:14         17
# 87224 2016-06-20 17:40:13         17
# 87250 2016-06-20 18:40:17         18
# 87285 2016-06-20 20:31:15         20
# 87288 2016-06-20 20:40:12         20
# 87900 2016-06-22 07:48:00          7
# 87999 2016-06-22 14:20:11         14
# 88030 2016-06-22 15:23:12         15
# 88036 2016-06-22 15:40:12         15
#
# [7820 rows x 13 columns]

# %%
articlesg0['Topic'].value_counts()
# Out:
# microsoft    7084
# palestine     736
# Name: Topic, dtype: int64

# %% [markdown]
# How sentimentTitle and Sentiment headings are spread?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,4))
plt.title('Sentiment Title: Microsoft')
plt.hist(combined['SentimentTitle'][combined.Topic=='microsoft'])
plt.show()
plt.figure(figsize=(10,4))
plt.title('Sentiment Title: Palestine')
plt.hist(combined['SentimentTitle'][combined.Topic=='palestine'])
plt.show()
plt.figure(figsize=(10,4))
plt.title('Sentiment Headline: Microsoft')
plt.hist(combined['SentimentHeadline'][combined.Topic=='microsoft'])
plt.show()
plt.figure(figsize=(10,4))
plt.title('Sentiment Headline: Palestine')
plt.hist(combined['SentimentHeadline'][combined.Topic=='palestine'])
plt.show()

# %%
import matplotlib.pyplot as plt

#First plot
plt.figure() #figsize and dpi are optional plt.figure(figsize=[3,2], dpi=300) 
plt.hist(combined['SentimentHeadline'][combined.Topic=='palestine'])
#Second plot
plt.figure()
plt.hist(combined['SentimentHeadline'][combined.Topic=='palestine'])

plt.show() #Optional: I mostly use IPython with %matplotlib inline

# %% [raw]
# # Try to summarize to article and headlines. (We'll discuss this in details in this week)

# %%
import pandas as pd
import nltk
import numpy as np

# %%
from sumy.summarizers.lex_rank import LexRankSummarizer
from sumy.nlp.stemmers import Stemmer
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer

# %%
combined['Headline']=combined['Headline'].astype('str')

# %%
headline=combined.Headline

# %%
values = ','.join(map(str, headline))

# %%
parser = PlaintextParser.from_string(values, Tokenizer("english"))

# %%
summarizer = LexRankSummarizer()
sentences = summarizer(parser.document, 10)
sentences

# %%
article=combined.Title

# %%
values1 = '.'.join(map(str, article))

# %%
parser = PlaintextParser.from_string(values1, Tokenizer("english"))

# %%
summarizer = LexRankSummarizer()
sentences = summarizer(parser.document, 10)
sentences

# %% [markdown]
# For each topic (microsoft and palestine), how many news article are present in their individual social media platform file.

# %%
lpalestine=pd.read_csv('LinkedIn_Palestine.csv')

# %%
lpalestine.shape

# %%
lmicrosoft=pd.read_csv('LinkedIn_Microsoft.csv')

# %%
lmicrosoft.shape

# %%
gpalestine=pd.read_csv('GooglePlus_Palestine.csv')

# %%
gpalestine.shape

# %%
gmicrosoft=pd.read_csv('GooglePlus_Microsoft.csv')

# %%
gmicrosoft.shape

# %%
fpalestine=pd.read_csv('Facebook_Palestine.csv')

# %%
fpalestine.shape

# %%
fmicrosoft=pd.read_csv('Facebook_Microsoft.csv')

# %%
fmicrosoft.shape

# %% [markdown]
# How are the data spread in separate file for each social media platform file for articles with Facebook/Googleplus/Linkedin values are -1.

# %%
#WE ARE CREATING COLUMNS FOR MONTHE ,DATE,YEAR,MONTH_NAME,WEEKDAY
combined['month'] = combined['Date'].dt.month
combined['day'] = combined['Date'].dt.day
combined['year'] = combined['Date'].dt.year
combined['month_name'] = combined['Date'].dt.strftime('%b')
combined['weekday'] = combined['Date'].dt.strftime('%A')

# %% [raw]
# What meaning is coming out of Facebook/Googleplus/Linkedin columns with columns -1 and 0

# %%
articlesl0=combined.loc[((combined.Facebook <=0) & (combined.LinkedIn<=0) &(combined.GooglePlus <= 0)),:]

# %%
articlesl0.head()

# %%
articlesl0.shape

# %%
articlesl0['Topic'].value_counts()

# %%
articlesg0['Topic'].value_counts()

# %%
combined['Topic'].value_counts()

# %%
articlesl0.time_hour.value_counts().head()

# %%
articlesl0.time_hour[articlesl0['Topic']=='palestine'].value_counts().head()

# %%
articlesl0.time_hour[articlesl0['Topic']=='microsoft'].value_counts().head()

# %%
articlesl0.month[articlesl0['Topic']=='microsoft'].value_counts().head()

# %%
articlesl0.month[articlesl0['Topic']=='palestine'].value_counts().head()

# %%
articlesl0['month'].value_counts().head()

# %%
sns.countplot(articlesl0['month'])
plt.show()

# %%
articlesl0['day'].value_counts().head()

# %%
articlesl0.day[articlesl0['Topic']=='palestine'].value_counts().head()

# %%
articlesl0.day[articlesl0['Topic']=='microsoft'].value_counts().head()

# %%
plt.hist(articlesl0['SentimentTitle'])
plt.show()

# %%
plt.hist(articlesg0['SentimentTitle'])
plt.show()

# %%
plt.hist(combined['SentimentTitle'])
plt.show()

# %%
articlesl0['SentimentTitle'].skew()

# %%
combined['SentimentTitle'].skew()

# %%
articlesg0['SentimentTitle'].skew()

# %%
articlesl0['Source'].value_counts()

# %%
articlesg0['Source'].value_counts().head()

# %%
combined['Source'].value_counts().head()
