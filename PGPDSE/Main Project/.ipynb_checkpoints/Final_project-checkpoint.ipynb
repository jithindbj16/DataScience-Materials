# %%
import pandas as pd
import nltk
import gensim
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('News_Final.csv')
df.head(11)
# Out:
#      IDLink                                              Title  \
# 0   99248.0   Obama Lays Wreath at Arlington National Cemetery
# 1   10423.0        A Look at the Health of the Chinese Economy
# 2   18828.0   Nouriel Roubini: Global Economy Not Back to 2008
# 3   27788.0                          Finland GDP Expands In Q4
# 4   27789.0  Tourism, govt spending buoys Thai economy in J...
# 5   27790.0  Intellitec Solutions to Host 13th Annual Sprin...
# 6   80690.0                                Monday, 29 Feb 2016
# 7   80762.0  Obama, stars pay a musical tribute to Ray Charles
# 8   80771.0  Fire claims more than 100-year-old barn in Han...
# 9   27803.0        Microsoft's new Windows 10 ad targets Apple
# 10  27813.0  Microsoft Project Centennial seen with “univer...
#
#                                              Headline  \
# 0   Obama Lays Wreath at Arlington National Cemete...
# 1   Tim Haywood, investment director business-unit...
# 2   Nouriel Roubini, NYU professor and chairman at...
# 3   Finland's economy expanded marginally in the t...
# 4   Tourism and public spending continued to boost...
# 5   Over 100 attendees expected to see latest vers...
# 6   RAMALLAH, February 25, 2016 (WAFA) - Palestine...
# 7   First lady Michelle Obama speaks in the State ...
# 8   A Hancock County man lost a barn early Monday ...
# 9   New Delhi, Feb.29 : Technology giant Microsoft...
# 10  Microsoft may have burned off one bridge, but ...
#
#                                       Source      Topic          PublishDate  \
# 0                                  USA TODAY      obama  2002-04-02 00:00:00
# 1                                  Bloomberg    economy  2008-09-20 00:00:00
# 2                                  Bloomberg    economy  2012-01-28 00:00:00
# 3                                   RTT News    economy  2015-03-01 00:06:00
# 4   The Nation - Thailand&#39;s English news    economy  2015-03-01 00:11:00
# 5                                      PRWeb  microsoft  2015-03-01 00:19:00
# 6                                        NaN  palestine  2016-02-28 14:03:00
# 7                             Coast Reporter      obama  2015-03-01 00:45:00
# 8                          WTHR Indianapolis  palestine  2015-03-01 01:20:00
# 9                                 New Kerala  microsoft  2015-03-01 01:32:00
# 10                                 SlashGear  microsoft  2015-03-01 02:14:00
#
#     SentimentTitle  SentimentHeadline  Facebook  GooglePlus  LinkedIn
# 0         0.000000          -0.053300        -1          -1        -1
# 1         0.208333          -0.156386        -1          -1        -1
# 2        -0.425210           0.139754        -1          -1        -1
# 3         0.000000           0.026064        -1          -1        -1
# 4         0.000000           0.141084        -1          -1        -1
# 5        -0.075378           0.036773        -1          -1        -1
# 6         0.000000          -0.005906         0           0         0
# 7         0.083333           0.103003        -1          -1        -1
# 8        -0.173925          -0.050185        -1          -1        -1
# 9        -0.059536          -0.081715        -1          -1        -1
# 10        0.000000           0.002550        -1          -1        -1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93239 entries, 0 to 93238
# Data columns (total 11 columns):
# IDLink               93239 non-null float64
# Title                93239 non-null object
# Headline             93224 non-null object
# Source               92960 non-null object
# Topic                93239 non-null object
# PublishDate          93239 non-null object
# SentimentTitle       93239 non-null float64
# SentimentHeadline    93239 non-null float64
# Facebook             93239 non-null int64
# GooglePlus           93239 non-null int64
# LinkedIn             93239 non-null int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 7.8+ MB

# %%
ndf=pd.concat([df[df['Topic']=='microsoft'],df[df['Topic']=='palestine']],axis=0)

# %%
#ndf=ndf[(ndf.Facebook>-1) & (ndf.GooglePlus>-1) & (ndf.LinkedIn >-1)]

# %%
docs=ndf['Title'][0:5].fillna('').str.lower()
docs=docs.str.replace('[^a-z ]','')
docs
# Out:
# 5     intellitec solutions to host th annual spring ...
# 9              microsofts new windows  ad targets apple
# 10    microsoft project centennial seen with univers...
# 11    microsoft sneaks onto android while android sn...
# 14     hololens dev edition costs  with new conker game
# Name: Title, dtype: object

# %%
stopwords=nltk.corpus.stopwords.words('english')
stopwords.extend(['use','','will','one','good'])
stemmer=nltk.stem.PorterStemmer()

docs_clean=[]
for doc in docs:
    words=doc.split(' ')
    words_clean= [stemmer.stem(word) for word in words if word not in stopwords]
    words_clean=[word for word in words_clean if word not in stopwords]
    docs_clean.append(words_clean)

# %%
dictionary = gensim.corpora.Dictionary(docs_clean) # to get the id for every single word

# %%
docs_bow=[]
for doc in docs_clean:
    bow=dictionary.doc2bow(doc)
    docs_bow.append(bow)

# %%
lda_model=gensim.models.LdaMulticore(docs_bow,id2word=dictionary,num_topics=4,random_state=100)

# %%
topics=[]
for doc in docs_bow:
    new_df=pd.DataFrame(lda_model.get_document_topics(doc),columns=['topics','probs'])
    topic=new_df.sort_values(by='probs').iloc[-1]['topics']
    topics.append(topic)

# %%
ndf.shape
# Out:
# (30701, 11)

# %%
ndf.shape
# Out:
# (30701, 11)

# %%
df[df['Topic']=='microsoft'].shape
# Out:
# (21858, 11)

# %%
df[df['Topic']=='palestine'].shape
# Out:
# (8843, 11)

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30701 entries, 5 to 93237
# Data columns (total 11 columns):
# IDLink               30701 non-null float64
# Title                30701 non-null object
# Headline             30697 non-null object
# Source               30462 non-null object
# Topic                30701 non-null object
# PublishDate          30701 non-null object
# SentimentTitle       30701 non-null float64
# SentimentHeadline    30701 non-null float64
# Facebook             30701 non-null int64
# GooglePlus           30701 non-null int64
# LinkedIn             30701 non-null int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 2.8+ MB

# %%
ndf.isnull().sum()
# Out:
# IDLink                 0
# Title                  0
# Headline               4
# Source               239
# Topic                  0
# PublishDate            0
# SentimentTitle         0
# SentimentHeadline      0
# Facebook               0
# GooglePlus             0
# LinkedIn               0
# dtype: int64

# %%
ndf.Source.fillna(ndf.Source.mode()[0],inplace=True)

# %%
ndf.isnull().sum()
# Out:
# IDLink               0
# Title                0
# Headline             4
# Source               0
# Topic                0
# PublishDate          0
# SentimentTitle       0
# SentimentHeadline    0
# Facebook             0
# GooglePlus           0
# LinkedIn             0
# dtype: int64

# %%
ndf.Topic.value_counts()/30701*100
# Out:
# microsoft    71.196378
# palestine    28.803622
# Name: Topic, dtype: float64

# %%
# to replace null value for heading - need to discuss with the mentor

# %%
ndf.dtypes
# Out:
# IDLink               float64
# Title                 object
# Headline              object
# Source                object
# Topic                 object
# PublishDate           object
# SentimentTitle       float64
# SentimentHeadline    float64
# Facebook               int64
# GooglePlus             int64
# LinkedIn               int64
# dtype: object

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30701 entries, 5 to 93237
# Data columns (total 11 columns):
# IDLink               30701 non-null float64
# Title                30701 non-null object
# Headline             30697 non-null object
# Source               30701 non-null object
# Topic                30701 non-null object
# PublishDate          30701 non-null object
# SentimentTitle       30701 non-null float64
# SentimentHeadline    30701 non-null float64
# Facebook             30701 non-null int64
# GooglePlus           30701 non-null int64
# LinkedIn             30701 non-null int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 2.8+ MB

# %%
ndf[['Source','SentimentHeadline']].groupby('Source').agg('median').sort_values(by='SentimentHeadline',ascending=True)
# Out:
#                                          SentimentHeadline
# Source
# KELO AM-FM                                       -0.604606
# Grist                                            -0.491652
# MegaGames                                        -0.473039
# CBS Sports                                       -0.472456
# Yahoo Tech via Yahoo! News                       -0.463606
# Hackaday                                         -0.451564
# The Market Mogul                                 -0.438194
# Australia-Israel Jewish Affairs Council          -0.434111
# The Holmes Report                                -0.409159
# Nightcap TV                                      -0.404789
# The Conroe Courier                               -0.401950
# Georgetown University The Hoya                   -0.398300
# OSNews                                           -0.397764
# Teague Chronicle                                 -0.395833
# Upvoted                                          -0.376354
# Limerick Post                                    -0.374877
# NZ Newswire via Yahoo! New Zealand News          -0.369215
# Bath Chronicle                                   -0.343750
# Business Management Daily                        -0.342451
# 12news.com                                       -0.340965
# Storypick                                        -0.327981
# CBS San Francisco                                -0.327327
# Mashable via Yahoo! News                         -0.319596
# The Elkhart Truth                                -0.319464
# The Daily Freeman                                -0.318944
# Times of India (blog)                            -0.311468
# The Escapist                                     -0.303593
# The Examiner                                     -0.299397
# The Bottom Line                                  -0.298718
# The Tablet                                       -0.297778
# ...                                                    ...
# Kitchener - Waterloo Record                       0.252955
# PRWeek                                            0.254019
# WMCTV Memphis                                     0.255972
# The Morganton News Herald                         0.258093
# WESH Orlando                                      0.261321
# Examiner.com                                      0.262597
# Test Tube                                         0.263395
# Eurosport                                         0.265953
# Sudan Tribune                                     0.266537
# MSPmentor (blog)                                  0.277887
# News-Medical.net                                  0.279896
# KHQ Right Now                                     0.279896
# News Radio 710 KEEL                               0.290689
# Frost Illustrated                                 0.294201
# Campus Technology                                 0.299616
# Emergency Management (blog)                       0.299814
# Broadband TV News                                 0.307459
# The Panther                                       0.310006
# Kenai Peninsula Online                            0.319663
# WECT 6 Wilmington                                 0.336857
# WBTV Charlotte                                    0.338697
# Sportsnet.ca                                      0.368231
# ICRC (press release)                              0.384324
# ZME Science                                       0.398144
# Dothan Eagle                                      0.452267
# Bowling Green Daily News                          0.452267
# Hickory Daily Record                              0.452267
# Killeen Daily Herald                              0.452267
# Technical.ly Brooklyn                             0.465986
# Northwest Georgia News                            0.964646
#
# [3323 rows x 1 columns]

# %%
ndf[['Source','SentimentTitle']].groupby('Source').agg('median').sort_values(by='SentimentTitle',ascending=True)
# Out:
#                                                     SentimentTitle
# Source
# KOLO                                                     -0.477297
# CBS Sports                                               -0.472456
# Entertainment Weekly                                     -0.469342
# INFORUM                                                  -0.458333
# Wilts and Gloucestershire Standard                       -0.452267
# Anderson Independent Mail                                -0.447214
# Cloud Computing Intelligence (registration)              -0.419166
# shanghaidaily                                            -0.392837
# The Connecticut College Voice                            -0.355756
# Daily Aztec                                              -0.353225
# Outer Places                                             -0.343750
# Norman Transcript                                        -0.341233
# RiversideGazette.com                                     -0.333333
# Around the Rings (subscription)                          -0.330719
# FinalCall.com News                                       -0.329931
# Kasmir Monitor                                           -0.320408
# Technical.ly                                             -0.316725
# Naked Security (blog)                                    -0.316228
# Bath Chronicle                                           -0.316228
# KGO-TV Bay Area                                          -0.309359
# Times Record (subscription)                              -0.302083
# The Tidings                                              -0.302083
# Catholic News Agency                                     -0.302083
# MSNBC                                                    -0.300122
# Daily News | The National Newspaper (press rele...       -0.299303
# Australia-Israel Jewish Affairs Council                  -0.291667
# KCCI Des Moines                                          -0.289200
# Council on Foreign Relations (blog)                      -0.284923
# VentureVillage                                           -0.284923
# Georgetown University The Hoya                           -0.279508
# ...                                                            ...
# The Spokesman-Review                                      0.239811
# Industry Week                                             0.245009
# DailyPost Nigeria                                         0.247053
# Beloit Daily News                                         0.250000
# The FINANCIAL                                             0.250000
# Memeburn                                                  0.251195
# Albany Times Union                                        0.253048
# Wall Street Daily                                         0.255155
# Pittsburgh Post-Gazette                                   0.257989
# Brian Madden (blog)                                       0.260016
# KFGO                                                      0.260229
# The Edge Markets MY                                       0.265165
# BusinessWorld Online Edition                              0.276214
# The Whistler                                              0.276699
# PSX Extreme                                               0.283473
# Webster Journal                                           0.292173
# Global Times                                              0.295931
# Technical.ly Brooklyn                                     0.306186
# News-Medical.net                                          0.309359
# Warc                                                      0.330752
# The Chicago Monitor                                       0.347768
# The Advertiser                                            0.359375
# Prince George Citizen                                     0.375000
# Sportsnet.ca                                              0.375000
# Santa Fe Reporter                                         0.375000
# 4k                                                        0.376889
# Mensquare                                                 0.395292
# ChinaTopix                                                0.474342
# Focus News                                                0.500000
# Yahoo Tech via Yahoo! News                                0.714610
#
# [3323 rows x 1 columns]

# %%
ndf[['Topic','SentimentTitle','SentimentHeadline']].groupby('Topic').agg('mean').sort_values(by='SentimentHeadline',ascending=False)
# Out:
#            SentimentTitle  SentimentHeadline
# Topic
# microsoft        0.002359          -0.014744
# palestine       -0.020085          -0.044485

# %%
ndf['Date']=pd.to_datetime(ndf['PublishDate'])

# %%
ndf['month'] = ndf['Date'].dt.month
ndf['day'] = ndf['Date'].dt.day
ndf['year'] = ndf['Date'].dt.year
ndf['month_name'] = ndf['Date'].dt.strftime('%b')
ndf['weekday'] = ndf['Date'].dt.strftime('%A')

# %%
ndf['Date'].min(), ndf['Date'].max()
# Out:
# (Timestamp('2015-03-01 00:19:00'), Timestamp('2016-07-07 16:16:11'))

# %%
ndf.month_name.value_counts()
# Out:
# Mar    4283
# Jan    4211
# Dec    3857
# May    3678
# Jun    3639
# Apr    3598
# Feb    3511
# Nov    3021
# Jul     680
# Oct     219
# Sep       3
# Aug       1
# Name: month_name, dtype: int64

# %%
ndf.weekday.value_counts()
# Out:
# Monday       5672
# Tuesday      5638
# Wednesday    5421
# Thursday     5127
# Friday       4287
# Sunday       2322
# Saturday     2234
# Name: weekday, dtype: int64

# %%
ndf[['month_name','Topic','IDLink']].groupby(['month_name','Topic']).agg('count')
# Out:
#                       IDLink
# month_name Topic
# Apr        microsoft    2609
#            palestine     989
# Aug        microsoft       1
# Dec        microsoft    2664
#            palestine    1193
# Feb        microsoft    2396
#            palestine    1115
# Jan        microsoft    2864
#            palestine    1347
# Jul        microsoft     492
#            palestine     188
# Jun        microsoft    2703
#            palestine     936
# Mar        microsoft    3028
#            palestine    1255
# May        microsoft    2719
#            palestine     959
# Nov        microsoft    2259
#            palestine     762
# Oct        microsoft     123
#            palestine      96
# Sep        palestine       3

# %%
ndf[['month_name','Topic','IDLink']].groupby(['month_name','Topic']).agg('count').sort_values(by='IDLink',ascending=False)
# Out:
#                       IDLink
# month_name Topic
# Mar        microsoft    3028
# Jan        microsoft    2864
# May        microsoft    2719
# Jun        microsoft    2703
# Dec        microsoft    2664
# Apr        microsoft    2609
# Feb        microsoft    2396
# Nov        microsoft    2259
# Jan        palestine    1347
# Mar        palestine    1255
# Dec        palestine    1193
# Feb        palestine    1115
# Apr        palestine     989
# May        palestine     959
# Jun        palestine     936
# Nov        palestine     762
# Jul        microsoft     492
#            palestine     188
# Oct        microsoft     123
#            palestine      96
# Sep        palestine       3
# Aug        microsoft       1

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30701 entries, 5 to 93237
# Data columns (total 17 columns):
# IDLink               30701 non-null float64
# Title                30701 non-null object
# Headline             30697 non-null object
# Source               30701 non-null object
# Topic                30701 non-null object
# PublishDate          30701 non-null object
# SentimentTitle       30701 non-null float64
# SentimentHeadline    30701 non-null float64
# Facebook             30701 non-null int64
# GooglePlus           30701 non-null int64
# LinkedIn             30701 non-null int64
# Date                 30701 non-null datetime64[ns]
# month                30701 non-null int64
# day                  30701 non-null int64
# year                 30701 non-null int64
# month_name           30701 non-null object
# weekday              30701 non-null object
# dtypes: datetime64[ns](1), float64(3), int64(6), object(7)
# memory usage: 4.2+ MB

# %%
ndf['GooglePlus'].value_counts()
# Out:
#  0       15928
#  1        3590
# -1        2690
#  2        1980
#  3        1257
#  4         838
#  5         663
#  6         449
#  7         377
#  8         291
#  9         242
#  10        212
#  11        189
#  12        158
#  13        147
#  15        111
#  14        105
#  17         81
#  18         73
#  21         65
#  16         64
#  19         62
#  20         59
#  22         56
#  23         52
#  24         45
#  26         37
#  25         36
#  27         34
#  28         32
#          ...
#  281         1
#  212         1
#  247         1
#  244         1
#  436         1
#  117         1
#  165         1
#  197         1
#  134         1
#  150         1
#  214         1
#  230         1
#  103         1
#  135         1
#  231         1
#  263         1
#  201         1
#  367         1
#  423         1
#  88          1
#  104         1
#  152         1
#  168         1
#  216         1
#  392         1
#  504         1
#  1016        1
#  121         1
#  169         1
#  407         1
# Name: GooglePlus, Length: 204, dtype: int64

# %%
ndf['Topic'] = ndf['Topic'].str.lower().str.replace('[^a-z#@ ]', '')
ndf['microsoft'] = ndf['Topic'].apply(lambda v: 1 if 'microsoft' in v.split(' ') else 0)
ndf['microsoft'].value_counts()
# Out:
# 1    21858
# 0     8843
# Name: microsoft, dtype: int64

# %%
ndf['palestine'] = ndf['Topic'].apply(lambda v: 1 if 'palestine' in v.split(' ') else 0)

# %%
ndf=ndf[(ndf.Facebook>-1)&(ndf.GooglePlus>-1)&(ndf.LinkedIn>-1)]

# %%
# Topics per month comparison

plt.figure(figsize=(12,8))
ndf.index = ndf['Date']
ndf.resample('1M')['microsoft'].sum().plot.line()
ndf.resample('1M')['palestine'].sum().plot.line()
plt.legend()
plt.xlabel("Month")
plt.title('No of airticles Published : Microsoft VS Palestine')
plt.show()

# %%
ndf.month.value_counts()
# Out:
# 1     3935
# 3     3724
# 12    3606
# 5     3364
# 4     3314
# 2     3313
# 11    2519
# 6     1757
# 7      132
# Name: month, dtype: int64

# %%
ndf['PublishDate'] = ndf.PublishDate.astype('str')
ndf['Date'] = ndf['PublishDate'].str[0:7]
ndf['Date'] = pd.to_datetime(ndf['Date'])
ndf.head(2)
# Out:
#                      IDLink  \
# Date
# 2015-11-08 05:25:00   311.0
# 2015-11-08 06:54:00   307.0
#
#                                                                  Title  \
# Date
# 2015-11-08 05:25:00  Microsoft offering £100 discount on original B...
# 2015-11-08 06:54:00    Microsoft scales back free online storage plans
#
#                                                               Headline  \
# Date
# 2015-11-08 05:25:00  Just ahead of the market rollout of Microsoft'...
# 2015-11-08 06:54:00  NEW YORK — Microsoft is getting stingy with on...
#
#                                                                 Source  \
# Date
# 2015-11-08 05:25:00  International Business Times via Yahoo UK & Ir...
# 2015-11-08 06:54:00                                      The Columbian
#
#                          Topic          PublishDate  SentimentTitle  \
# Date
# 2015-11-08 05:25:00  microsoft  2015-11-08 05:25:00        0.000000
# 2015-11-08 06:54:00  microsoft  2015-11-08 06:54:00        0.106303
#
#                      SentimentHeadline  Facebook  GooglePlus  LinkedIn  \
# Date
# 2015-11-08 05:25:00          -0.132812         0           0         0
# 2015-11-08 06:54:00          -0.207333         0           0         0
#
#                           Date  month  day  year month_name weekday  \
# Date
# 2015-11-08 05:25:00 2015-11-01     11    8  2015        Nov  Sunday
# 2015-11-08 06:54:00 2015-11-01     11    8  2015        Nov  Sunday
#
#                      microsoft  palestine
# Date
# 2015-11-08 05:25:00          1          0
# 2015-11-08 06:54:00          1          0

# %%
# avarage sentiments of economy and obama
plt.figure(figsize=(12,8))
print('Sentiment Title\n')
for i in ndf.Topic.unique():
    plt.plot(ndf[ndf['Topic']==i].groupby(['Date']).SentimentTitle.mean(),label=i)
plt.xticks(rotation=0)
plt.xlabel('Year_Month')
plt.ylabel('Sentiment Score')
plt.title('Sentiment Title')
plt.legend()
plt.show()


plt.figure(figsize=(12,8))
print('Sentiment HeadLine\n')
for i in ndf.Topic.unique():
    plt.plot(ndf[ndf['Topic']==i].groupby(['Date']).SentimentHeadline.mean(),label=i)
plt.xticks(rotation=0)
plt.xlabel('Year_Month')
plt.ylabel('Sentiment Score')
plt.title('Sentiment Headline')
plt.legend()
plt.show()
# Out:
# Sentiment Title
# C:\Users\lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: 'Date' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
# Sentiment HeadLine
# C:\Users\lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: 'Date' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
