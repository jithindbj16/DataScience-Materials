# %%
import pandas as pd
import numpy as np

# %%
series1=pd.Series([10,20,30,40])
print(series1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
series1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
series1.values
# Out:
# array([10, 20, 30, 40], dtype=int64)

# %%
series2=pd.Series([1,2,3,4,5],index=["one","two","Three","Four","five"])
series2
# Out:
# one      1
# two      2
# Three    3
# Four     4
# five     5
# dtype: int64

# %%
series2["one"]
# Out:
# 1

# %%
l1=[1,2,3]

# %%
series2[series2>1]
# Out:
# two      2
# Three    3
# Four     4
# five     5
# dtype: int64

# %%
key=range(1,16)
dic1=dict((x,x**2) for x in key)
print(dic1)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
myd = {"Orange":1,"Apple":2,"Grapes":3, "Apple":1} # myd is a dictonary type  # we get sorted values and  works only in python 2.7
mytab = pd.Series(myd)
#print(mytab) # note that the series data will be sorted 
type(mytab)
print(mytab[1]) #This will print only the values from the series ! 
mytab.index
# Out:
# 1
# Index(['Orange', 'Apple', 'Grapes'], dtype='object')

# %%
pd.isnull(mytab)
# Out:
# Orange    False
# Apple     False
# Grapes    False
# dtype: bool

# %%
dic1={1:10,2:20} 
dic2={3:30,4:40} 
dic3={5:50,6:60}
dic4=dict()
dic4.update(dic1)
dic4.update(dic2)
dic4.update(dic3)
dic4
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
df=pd.DataFrame({"Name":["Jithin","Alexander"],"Age":[23,34]})
df
# Out:
#         Name  Age
# 0     Jithin   23
# 1  Alexander   34

# %%
df=df.drop(1)
df
# Out:
#      Name  Age
# 0  Jithin   23

# %%
df.T
# Out:
#            0
# Name  Jithin
# Age       23

# %%
ndf=df.reindex(index=[0,2],columns=["Name"])

# %%
ndf
# Out:
#      Name
# 0  Jithin
# 2     NaN

# %%
ndf = df.reindex([-1,0,1,2,3], method='bfill')
ndf
# Out:
#          Name   Age
# -1     Jithin  23.0
#  0     Jithin  23.0
#  1  Alexander  34.0
#  2        NaN   NaN
#  3        NaN   NaN

# %%
ndf = df.reindex([-1,0,1,2,3], method='ffill')
ndf
# Out:
#          Name   Age
# -1        NaN   NaN
#  0     Jithin  23.0
#  1  Alexander  34.0
#  2  Alexander  34.0
#  3  Alexander  34.0

# %%
from numpy.random import randint
df1=pd.DataFrame(np.array(randint(15,30,9).reshape(3,3)),columns=["One","Two","Three"])
df1
# Out:
#    One  Two  Three
# 0   22   27     28
# 1   28   25     15
# 2   21   23     22

# %%
df2=df1.rename(columns={"One":"First","Two":"Second","Three":"Third"},index={0:1,1:2,2:3})

# %%
df2
# Out:
#    First  Second  Third
# 1     22      27     28
# 2     28      25     15
# 3     21      23     22

# %%
mycars = pd.read_csv('motor_cars.csv')   # give the file and location inside the brackets
mycars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive   NaN    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df1.rename(columns={"One":"First","Two":"Second","Three":"Third"},index={0:1,1:2,2:3},inplace=True)

# %%
df1
# Out:
#    First  Second  Third
# 1     22      27     28
# 2     28      25     15
# 3     21      23     22

# %%
# Lets rename the first column (scroll up for the see the default name)
mycars.rename(columns={'Unnamed: 0' : 'car_model'}, inplace=True)

# The below code will print all the column names in the data frame 
for col in mycars:
    print(col)
# Out:
# car_model
# mpg
# cyl
# disp
# hp
# drat
# wt
# qsec
# vs
# am
# gear
# carb

# %%
headcars = mycars.head()


for key,value in headcars.iteritems():
    print (key,value)
# Out:
# car_model 0            Mazda RX4
# 1        Mazda RX4 Wag
# 2           Datsun 710
# 3       Hornet 4 Drive
# 4    Hornet Sportabout
# Name: car_model, dtype: object
# mpg 0    21.0
# 1    21.0
# 2    22.8
# 3     NaN
# 4    18.7
# Name: mpg, dtype: float64
# cyl 0    6
# 1    6
# 2    4
# 3    6
# 4    8
# Name: cyl, dtype: int64
# disp 0    160.0
# 1    160.0
# 2    108.0
# 3    258.0
# 4    360.0
# Name: disp, dtype: float64
# hp 0    110
# 1    110
# 2     93
# 3    110
# 4    175
# Name: hp, dtype: int64
# drat 0    3.90
# 1    3.90
# 2    3.85
# 3    3.08
# 4    3.15
# Name: drat, dtype: float64
# wt 0    2.620
# 1    2.875
# 2    2.320
# 3    3.215
# 4    3.440
# Name: wt, dtype: float64
# qsec 0    16.46
# 1    17.02
# 2    18.61
# 3    19.44
# 4    17.02
# Name: qsec, dtype: float64
# vs 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# Name: vs, dtype: int64
# am 0    1
# 1    1
# 2    1
# 3    0
# 4    0
# Name: am, dtype: int64
# gear 0    4
# 1    4
# 2    4
# 3    3
# ...

# %%
for i,j in headcars.iterrows():
     print(i,j)
# Out:
# 0 car_model    Mazda RX4
# mpg                 21
# cyl                  6
# disp               160
# hp                 110
# drat               3.9
# wt                2.62
# qsec             16.46
# vs                   0
# am                   1
# gear                 4
# carb                 4
# Name: 0, dtype: object
# 1 car_model    Mazda RX4 Wag
# mpg                     21
# cyl                      6
# disp                   160
# hp                     110
# drat                   3.9
# wt                   2.875
# qsec                 17.02
# vs                       0
# am                       1
# gear                     4
# carb                     4
# Name: 1, dtype: object
# 2 car_model    Datsun 710
# mpg                22.8
# cyl                   4
# disp                108
# hp                   93
# drat               3.85
# wt                 2.32
# qsec              18.61
# vs                    1
# am                    1
# gear                  4
# ...

# %%
sorted_cars=headcars.sort_index()
print(sorted_cars)
# Out:
#            car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive   NaN    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
topmpg = mycars.sort_values(by='mpg',ascending=False) 
topmpg
# Out:
#               car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# ...

# %%
import pandas as pd 
import numpy as np
import csv
data = pd.read_csv("wine.csv", encoding="latin-1")      # if we don't use latin then the latin values in the files would be imported with some irregurality
print(type(data))
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                       VulkÃ  Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
# ...

# %%
data[["points","price"]].mean()
# Out:
# points    88.447138
# price     35.363389
# dtype: float64

# %%
data.std(axis=0)
# Out:
# Unnamed: 0    37519.540256
# points            3.039730
# price            41.022218
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.hist(data["points"],bins=10)
# Out:
# (array([ 1089.,  4861., 16010., 29533., 29433., 26769., 16102.,  5293.,
#           752.,   129.]),
#  array([ 80.,  82.,  84.,  86.,  88.,  90.,  92.,  94.,  96.,  98., 100.]),
#  <a list of 10 Patch objects>)
