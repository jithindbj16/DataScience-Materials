# %% [markdown]
# # Fundamental types in Python

# %% [markdown]
# # Integers
# Integer literals are created by any number without a decimal or complex component.

# %%
x = 1
print(x)
y=5
print(y)
z="Test"
print(z)
# Out:
# 1
# 5
# Test

# %% [markdown]
# # Lets check if a number is integer or not

# %%
isinstance(x, int)
# Out:
# True

# %% [markdown]
# # Floats
# Float literals can be created by adding a decimal component to a number.

# %%
# No concept of declaring variable types in Python
x = 1.0
y = 5.7
print(y)
y=3
print(y)
y=5.6
print(x)
print(y)
# Out:
# 5.7
# 3
# 1.0
# 5.6

# %% [markdown]
# # Boolean
# Boolean can be defined by typing True/False without quotes

# %%
# Case Sensitive. True is different from TRUE. Dynamic Typing
b1 = True
print(b1)
b2 = False
b1 = 6
print(b1)
# Out:
# True
# 6

# %% [markdown]
# # Strings
# String literals can be defined with any of single quotes ('), double quotes (") or triple quotes (''' or """). All give the same result with two important differences.
#
# If you quote with single quotes, you do not have to escape double quotes and vice-versa. If you quote with triple quotes, your string can span multiple lines.

# %%
a="Test"
b=5
print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# string
name1 = 'your name'
print(name1)
name2 = "He's coming to the party"
print(name2)
name3 = '''XNews quotes : "He's coming to the party"'''
print(name3)
# Out:
# your name
# He's coming to the party
# XNews quotes : "He's coming to the party"

# %% [markdown]
# # Summary Statitics

# %%
  `
#byte_string = chr(195) + chr(167) + chr(97)
#unicode_string = byte_string.decode('latin-1')
#print(unicode_string) # prints: Ã§a
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Lets have a brief look at the first four rows of the data in table

# %%
data.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                       VulkÃ  Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN     Kerin OâKeefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                 Nicosia 2013 VulkÃ  Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2          @paulgwineÂ       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4          @paulgwineÂ   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
df = pd.DataFrame(data)
print (df)
# Out:
#         Unnamed: 0      country  \
# 0                0        Italy
# 1                1     Portugal
# 2                2           US
# 3                3           US
# 4                4           US
# 5                5        Spain
# 6                6        Italy
# 7                7       France
# 8                8      Germany
# 9                9       France
# 10              10           US
# 11              11       France
# 12              12           US
# 13              13        Italy
# 14              14           US
# 15              15      Germany
# 16              16    Argentina
# 17              17    Argentina
# 18              18        Spain
# 19              19           US
# 20              20           US
# 21              21           US
# 22              22        Italy
# 23              23           US
# 24              24        Italy
# 25              25           US
# 26              26        Italy
# 27              27        Italy
# 28              28        Italy
# 29              29           US
# ...            ...          ...
# 129941      129941           US
# 129942      129942           US
# 129943      129943        Italy
# 129944      129944       Israel
# 129945      129945           US
# 129946      129946      Germany
# 129947      129947        Italy
# 129948      129948    Argentina
# 129949      129949           US
# 129950      129950           US
# 129951      129951       France
# 129952      129952           US
# 129953      129953  New Zealand
# 129954      129954  New Zealand
# 129955      129955  New Zealand
# 129956      129956  New Zealand
# 129957      129957        Spain
# 129958      129958  New Zealand
# 129959      129959       France
# 129960      129960     Portugal
# 129961      129961        Italy
# 129962      129962        Italy
# 129963      129963       Israel
# 129964      129964       France
# 129965      129965       France
# 129966      129966      Germany
# 129967      129967           US
# 129968      129968       France
# 129969      129969       France
# 129970      129970       France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 16                                                  Felix      87   30.0
# 17                                    Winemaker Selection      87   13.0
# 18      Vendimia Seleccionada Finca Valdelayegua Singl...      87   28.0
# 19                                                    NaN      87   32.0
# 20                                          Vin de Maison      87   23.0
# 21                                                    NaN      87   20.0
# 22                                              Ficiligno      87   19.0
# 23                                    Signature Selection      87   22.0
# 24                                                  Aynat      87   35.0
# 25                                    King Ridge Vineyard      87   69.0
# 26                                                 Dalila      87   13.0
# 27                                                    NaN      87   10.0
# 28                                     Mascaria Barricato      87   17.0
# 29                                                    NaN      86   16.0
# ...                                                   ...     ...    ...
# 129941                                                NaN      90   20.0
# 129942                                                NaN      90   35.0
# 129943                                           AdÃ¨nzia      90   29.0
# 129944                 Special Reserve Winemakers' Choice      90   25.0
# 129945                   Jurassic Park Vineyard Old Vines      90   20.0
# 129946                                                Dom      90   17.0
# 129947                                           Symposio      90   20.0
# 129948                                           Pedernal      90   43.0
# 129949                                   Barrel Fermented      90   35.0
# 129950                                      Blocks 7 & 22      90   35.0
# 129951                                             Holder      90   30.0
# 129952                                                NaN      90   22.0
# 129953                                            Elspeth      90   25.0
# 129954                                      Single Estate      90   15.0
# 129955                                                NaN      90   40.0
# 129956  Gimblett Gravels Merlot-Cabernet Sauvignon-Malbec      90   19.0
# 129957                                            Crianza      90   17.0
# 129958                                           Irongate      90   35.0
# 129959                                    Brand Grand Cru      90   57.0
# 129960                                           VÃ©rtice      90   48.0
# 129961                                                NaN      90   30.0
# 129962                         SÃ gana Tenuta San Giacomo      90   40.0
# 129963                                           Oak Aged      90   20.0
# 129964                      Domaine Saint-RÃ©my Herrenweg      90    NaN
# 129965                       Seppi Landmann VallÃ©e Noble      90   28.0
# 129966            Brauneberger Juffer-Sonnenuhr SpÃ¤tlese      90   28.0
# 129967                                                NaN      90   75.0
# 129968                                              Kritt      90   30.0
# 129969                                                NaN      90   32.0
# 129970                     Lieu-dit Harth CuvÃ©e Caroline      90   21.0
#
#                  province               region_1           region_2  \
# 0       Sicily & Sardinia                   Etna                NaN
# 1                   Douro                    NaN                NaN
# 2                  Oregon      Willamette Valley  Willamette Valley
# 3                Michigan    Lake Michigan Shore                NaN
# 4                  Oregon      Willamette Valley  Willamette Valley
# 5          Northern Spain                Navarra                NaN
# 6       Sicily & Sardinia               Vittoria                NaN
# 7                  Alsace                 Alsace                NaN
# 8             Rheinhessen                    NaN                NaN
# 9                  Alsace                 Alsace                NaN
# 10             California            Napa Valley               Napa
# 11                 Alsace                 Alsace                NaN
# 12             California       Alexander Valley             Sonoma
# 13      Sicily & Sardinia                   Etna                NaN
# 14             California          Central Coast      Central Coast
# 15                  Mosel                    NaN                NaN
# 16                  Other               Cafayate                NaN
# 17       Mendoza Province                Mendoza                NaN
# 18         Northern Spain       Ribera del Duero                NaN
# 19               Virginia               Virginia                NaN
# 20               Virginia               Virginia                NaN
# 21                 Oregon                 Oregon       Oregon Other
# 22      Sicily & Sardinia                Sicilia                NaN
# 23             California            Paso Robles      Central Coast
# 24      Sicily & Sardinia                Sicilia                NaN
# 25             California           Sonoma Coast             Sonoma
# 26      Sicily & Sardinia        Terre Siciliane                NaN
# 27      Sicily & Sardinia        Terre Siciliane                NaN
# 28      Sicily & Sardinia  Cerasuolo di Vittoria                NaN
# 29             California             Clarksburg     Central Valley
# ...                   ...                    ...                ...
# 129941         California       Mendocino County                NaN
# 129942         California          Sonoma County             Sonoma
# 129943  Sicily & Sardinia                Sicilia                NaN
# 129944            Galilee                    NaN                NaN
# 129945         California      Santa Ynez Valley      Central Coast
# 129946              Mosel                    NaN                NaN
# 129947  Sicily & Sardinia        Terre Siciliane                NaN
# 129948              Other               San Juan                NaN
# 129949         California            Napa Valley               Napa
# 129950         California            Napa Valley               Napa
# 129951             Alsace                 Alsace                NaN
# 129952         California          Chiles Valley               Napa
# 129953        Hawke's Bay                    NaN                NaN
# 129954        Marlborough                    NaN                NaN
# 129955        Marlborough                    NaN                NaN
# 129956        Hawke's Bay                    NaN                NaN
# 129957     Northern Spain                  Rioja                NaN
# 129958        Hawke's Bay                    NaN                NaN
# 129959             Alsace                 Alsace                NaN
# 129960              Douro                    NaN                NaN
# 129961  Sicily & Sardinia                Sicilia                NaN
# 129962  Sicily & Sardinia                Sicilia                NaN
# 129963            Galilee                    NaN                NaN
# 129964             Alsace                 Alsace                NaN
# 129965             Alsace                 Alsace                NaN
# 129966              Mosel                    NaN                NaN
# 129967             Oregon                 Oregon       Oregon Other
# 129968             Alsace                 Alsace                NaN
# 129969             Alsace                 Alsace                NaN
# 129970             Alsace                 Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0          Kerin OâKeefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt          @paulgwineÂ
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt          @paulgwineÂ
# 5        Michael Schachner           @wineschach
# 6          Kerin OâKeefe          @kerinokeefe
# 7               Roger Voss            @vossroger
# 8       Anna Lee C. Iijima                   NaN
# 9               Roger Voss            @vossroger
# 10          Virginie Boone               @vboone
# 11              Roger Voss            @vossroger
# 12          Virginie Boone               @vboone
# 13         Kerin OâKeefe          @kerinokeefe
# 14           Matt Kettmann         @mattkettmann
# 15      Anna Lee C. Iijima                   NaN
# 16       Michael Schachner           @wineschach
# 17       Michael Schachner           @wineschach
# 18       Michael Schachner           @wineschach
# 19      Alexander Peartree                   NaN
# 20      Alexander Peartree                   NaN
# 21            Paul Gregutt          @paulgwineÂ
# 22         Kerin OâKeefe          @kerinokeefe
# 23           Matt Kettmann         @mattkettmann
# 24         Kerin OâKeefe          @kerinokeefe
# 25          Virginie Boone               @vboone
# 26         Kerin OâKeefe          @kerinokeefe
# 27         Kerin OâKeefe          @kerinokeefe
# 28         Kerin OâKeefe          @kerinokeefe
# 29          Virginie Boone               @vboone
# ...                    ...                   ...
# 129941      Virginie Boone               @vboone
# 129942      Virginie Boone               @vboone
# 129943     Kerin OâKeefe          @kerinokeefe
# 129944       Mike DeSimone        @worldwineguys
# 129945       Matt Kettmann         @mattkettmann
# 129946  Anna Lee C. Iijima                   NaN
# 129947     Kerin OâKeefe          @kerinokeefe
# 129948   Michael Schachner           @wineschach
# 129949      Virginie Boone               @vboone
# 129950      Virginie Boone               @vboone
# 129951          Roger Voss            @vossroger
# 129952      Virginie Boone               @vboone
# 129953      Joe Czerwinski                @JoeCz
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...
# 129960  Caves Transmontanas 2006 VÃ©rtice Pinot Noir (...
# 129961                        COS 2013 Frappato (Sicilia)
# 129962  Cusumano 2012 SÃ gana Tenuta San Giacomo Nero ...
# 129963  Dalton 2012 Oak Aged Cabernet Sauvignon (Galilee)
# 129964  Domaine Ehrhart 2013 Domaine Saint-RÃ©my Herre...
# 129965  Domaine RieflÃ©-Landmann 2013 Seppi Landmann V...
# 129966  Dr. H. Thanisch (Erben MÃ¼ller-Burggraef) 2013...
# 129967                  Citation 2004 Pinot Noir (Oregon)
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970  Domaine Schoffit 2012 Lieu-dit Harth CuvÃ©e Ca...
#
#                          variety                                     winery
# 0                    White Blend                                    Nicosia
# 1                 Portuguese Red                        Quinta dos Avidagos
# 2                     Pinot Gris                                  Rainstorm
# 3                       Riesling                                 St. Julian
# 4                     Pinot Noir                               Sweet Cheeks
# 5             Tempranillo-Merlot                                     Tandem
# 6                       Frappato                            Terre di Giurfo
# 7                GewÃ¼rztraminer                                   Trimbach
# 8                GewÃ¼rztraminer                                Heinz Eifel
# 9                     Pinot Gris                         Jean-Baptiste Adam
# 10            Cabernet Sauvignon                         Kirkland Signature
# 11               GewÃ¼rztraminer                                 Leon Beyer
# 12            Cabernet Sauvignon                           Louis M. Martini
# 13             Nerello Mascalese                        Masseria Setteporte
# 14                    Chardonnay                                   Mirassou
# 15                      Riesling                           Richard BÃ¶cking
# 16                        Malbec                              Felix Lavaque
# 17                        Malbec                              Gaucho Andino
# 18             Tempranillo Blend                                   Pradorey
# 19                      Meritage                               QuiÃ©vremont
# 20                     Red Blend                               QuiÃ©vremont
# 21                    Pinot Noir                                    Acrobat
# 22                   White Blend                         Baglio di Pianetto
# 23                        Merlot                                    Bianchi
# 24                  Nero d'Avola                                 CanicattÃ¬
# 25                    Pinot Noir                        Castello di Amorosa
# 26                   White Blend                                   Stemmari
# 27                  Nero d'Avola                                   Stemmari
# 28                     Red Blend                            Terre di Giurfo
# 29                  Chenin Blanc                    Clarksburg Wine Company
# ...                          ...                                        ...
# 129941                Chardonnay                                    Apriori
# 129942        Cabernet Sauvignon                                   Arrowood
# 129943                 Red Blend            Baglio del Cristo di Campobello
# 129944                    Shiraz                                     Barkan
# 129945              Chenin Blanc                                  Birichino
# 129946                  Riesling             BischÃ¶fliche WeingÃ¼ter Trier
# 129947                 Red Blend                   Feudo Principi di Butera
# 129948                    Malbec                            Finca Las Moras
# 129949                Chardonnay                              Flora Springs
# 129950                 Zinfandel                                     Hendry
# 129951           GewÃ¼rztraminer                          Henri Schoenheitz
# 129952                 Zinfandel                                    Houdini
# 129953           Cabernet Merlot                                 Mills Reef
# 129954                Pinot Gris                                        Ara
# 129955                Chardonnay                                  Dog Point
# 129956  Bordeaux-style Red Blend                                 Esk Valley
# 129957         Tempranillo Blend                        ViÃ±edos Real Rubio
# 129958  Bordeaux-style Red Blend                                     Babich
# 129959                Pinot Gris                          Cave de Turckheim
# 129960                Pinot Noir                        Caves Transmontanas
# 129961                  Frappato                                        COS
# 129962              Nero d'Avola                                   Cusumano
# 129963        Cabernet Sauvignon                                     Dalton
# 129964           GewÃ¼rztraminer                            Domaine Ehrhart
# 129965                Pinot Gris                   Domaine RieflÃ©-Landmann
# 129966                  Riesling  Dr. H. Thanisch (Erben MÃ¼ller-Burggraef)
# 129967                Pinot Noir                                   Citation
# 129968           GewÃ¼rztraminer                            Domaine Gresser
# 129969                Pinot Gris                       Domaine Marcel Deiss
# 129970           GewÃ¼rztraminer                           Domaine Schoffit
#
# [129971 rows x 14 columns]

# %%
print (df.describe())
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
df.describe()     # shows only 3 columns because it gives out only numerical data
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# # Lets find out the mean of the wine score

# %%
data['points'].mean() #Mean of the dataframe:
# Out:
# 88.44713820775404

# %% [markdown]
# # Lets find out the column mean of the dataframe

# %%
df1 = data[['points','price']]
df1.mean(axis=0)
# Out:
# points    88.447138
# price     35.363389
# dtype: float64

# %% [raw]
# Note: axis=0 argument calculates the coloumn wise mean of the dataframe

# %% [markdown]
# # Row Mean of the dataframe:

# %%
df1.mean(axis=1).head()
# Out:
# 0    87.0
# 1    51.0
# 2    50.5
# 3    50.0
# 4    76.0
# dtype: float64

# %% [raw]
# Note: axis=1 argument calculates the row wise mean of the dataframe

# %% [markdown]
# # Lets calculate the median of the specific Column

# %%
data['points'].median()
# Out:
# 88.0

# %% [markdown]
# # Lets calculate the mode of the specific column

# %%
data['points'].mode()
# Out:
# 0    88
# dtype: int64

# %%
data['price'].std()
# Out:
# 41.02221766808889

# %% [markdown]
# # Lets calculate the standard deviation of a data frame

# %%
df.std()
# Out:
# Unnamed: 0    37519.540256
# points            3.039730
# price            41.022218
# dtype: float64

# %% [markdown]
# # Lets calculate the standard deviation of the data frame column wise

# %%
df.std(axis=0)
# Out:
# Unnamed: 0    37519.540256
# points            3.039730
# price            41.022218
# dtype: float64

# %% [markdown]
# # WAP - In class exe :Calculate the standard deviation of the data frame row wise?

# %%
dt=data.head()
dt.std(axis=1)
# Out:
# 0    61.518290
# 1    46.144700
# 2    46.003623
# 3    45.883911
# 4    43.000000
# dtype: float64

# %% [markdown]
# # Lets calculate the standard deviation of a specefic column "points"

# %%
df.loc[:,"points"].std()
# Out:
# 3.0397302029162336

# %% [markdown]
# # WAP - In class exe :Calculate the standard deviation of a specefic column "price"?

# %%
df.loc[:,"price"].std()
# Out:
# 41.02221766808889

# %%
df.var()
# Out:
# Unnamed: 0    1.407716e+09
# points        9.239960e+00
# price         1.682822e+03
# dtype: float64

# %% [markdown]
# # WAP - In class exe :Calculate the column and row variance of the data frame?

# %% [markdown]
# # Lets calculate the variance of a specefic column "points"

# %%
df.loc[:,"points"].var()
# Out:
# 9.239959706521168

# %% [markdown]
# # WAP - In class exe :Calculate the variance of a specefic column "price"?

# %% [markdown]
# # A complete measures of wine price

# %%
# dispersion measures
print('Min price : {0}'.format(df.price.min())) # minimum
print('Max price : {0}'.format(df.price.max())) # maximum
print('price range : {0}'.format(df.price.max()  - df.price.min())) # range
print('25 percentile : {0}'.format(df.price.quantile(.25))) # 25 percentile
print('50 percentile : {0}'.format(df.price.quantile(.5))) # 50 percentile
print('75 percentile : {0}'.format(df.price.quantile(.75))) # 75 percentile
print('Variance price : {0}'.format(df.price.var())) # variance
print('Standard deviation price : {0}'.format(df.price.std())) # standard deviation
# Out:
# Min price : 4.0
# Max price : 3300.0
# price range : 3296.0
# 25 percentile : 17.0
# 50 percentile : 25.0
# 75 percentile : 42.0
# Variance price : 1682.82234241
# Standard deviation price : 41.0222176681

# %% [markdown]
# # Visualization: Seaborne and matplotlib

# %% [raw]
# Lets use the same wine dataset for visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Lets display a Seaborn distplot

# %%
sns.distplot(df['points'])
plt.show()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Lets display a Seaborn distplot with dark background

# %%
sns.set_style('dark')
sns.distplot(df['points'])
plt.show()

# Clear the figure
plt.clf()
# Out:
# /Users/aniruddhakalbande/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # WAP - In class exe :Display a distplot for "price"?

# %% [markdown]
# # Lets display a distplot of "price" in 20 different bins

# %%
# Create a distplot
sns.distplot(df['points'],
             kde=False,
             bins=20)

# Display a plot
plt.show()
# Out:
# /Users/aniruddhakalbande/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Lets plot a histogram for points

# %%
df['points'].plot.hist()
plt.show()
plt.clf()

# %% [markdown]
# # WAP - In class exe :Plot histogram for "price"?

# %% [markdown]
# # Lets plot the same histogram with a default seaborn style

# %%
# Set the default seaborn style
sns.set()

# Plot the pandas histogram again
df['points'].plot.hist()
plt.show()
plt.clf()

# %% [markdown]
# # Lets display the above histogram with whitegrid using seaborn

# %%
# Plot with a whitegrid style
sns.set()
sns.set_style('whitegrid')
# Plot the pandas histogram again
df['points'].plot.hist()
plt.show()
plt.clf() #clears the graph

# %% [markdown]
# # Lets create a box plot for points and price

# %%
#Create a boxplot
sns.boxplot(data=df,
            x='points',
            y='price')

plt.show()
plt.clf()

# %% [markdown]
# # Lets create a bar plot for points and price

# %%
sns.barplot(data=df,
            x='points',
            y='price')

plt.show()
plt.clf()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Lets create scatter plot with respect to country and price

# %%
sns.regplot(data=df,
            y='points',
            x="price",
            fit_reg=False)

plt.show()
plt.clf()

# %% [markdown]
# # Lets check the skewness of the data

# %%
df.skew() #skewness value > 0 means that there is more weight in the left tail of the distribution.
# Out:
# Unnamed: 0     0.000000
# points         0.045921
# price         18.000957
# dtype: float64

# %%
print('skewness for points and price: {0:.2f} {1:.2f}'.format(df.points.skew(),df.price.skew()))
# Out:
# skewness for points and price: 0.05 18.00

# %%
print('skewness for price : {0:.2f}'.format(df.price.skew()))
# Out:
# skewness for price : 18.00

# %%
sns.distplot(df['points'], kde=False)
plt.show()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Outlier detection and treatment

# %% [raw]
# We are using the boston housing data set for this.

# %%
from sklearn.datasets import load_boston
boston = load_boston()
x = boston.data
y = boston.target
columns = boston.feature_names

# %%
#create the dataframe
boston_df = pd.DataFrame(boston.data)
boston_df.columns = columns
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# # Lets detect the outliers using visulaization tool

# %% [markdown]
# # 1.Boxplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=boston_df['DIS'])

# %% [raw]
# Above plot shows three points between 10 to 12

# %% [markdown]
# # 2.Scatter plot

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(boston_df['INDUS'], boston_df['TAX'])
ax.set_xlabel('Proportion of non-retail business acres per town')
ax.set_ylabel('Full-value property-tax rate per $10,000')
plt.show()

# %% [raw]
# we can see most of data points are lying bottom left side but there are points which are far from the population like top right corner.

# %% [markdown]
# # Lets detect the outliers using mathematical functions

# %% [markdown]
# # 1. Z-score

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(boston_df))
print(z)
# Out:
# [[0.41771335 0.28482986 1.2879095  ... 1.45900038 0.44105193 1.0755623 ]
#  [0.41526932 0.48772236 0.59338101 ... 0.30309415 0.44105193 0.49243937]
#  [0.41527165 0.48772236 0.59338101 ... 0.30309415 0.39642699 1.2087274 ]
#  ...
#  [0.41137448 0.48772236 0.11573841 ... 1.17646583 0.44105193 0.98304761]
#  [0.40568883 0.48772236 0.11573841 ... 1.17646583 0.4032249  0.86530163]
#  [0.41292893 0.48772236 0.11573841 ... 1.17646583 0.44105193 0.66905833]]

# %% [raw]
# It is difficult to say which data point is an outlier. Let’s try and define a threshold to identify an outlier.

# %% [markdown]
# # Lets define threshold for the above z-score to identify the outlier.

# %%
#threshold = 3
print(np.where(z > 3))
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#        200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#        220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#        277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#        357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#        380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#        416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#        437, 438, 445, 450, 454, 455, 456, 457, 466], dtype=int64), array([ 1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#         1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,
#         5,  3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,
#         3,  3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 12,  5, 12,  0,  0,  0,
#         0,  5,  0, 11, 11, 11, 12,  0, 12, 11, 11,  0, 11, 11, 11, 11, 11,
#        11,  0, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11],
#       dtype=int64))

# %% [raw]
# The first array contains the list of row numbers and second array respective column numbers, which mean z[55][1] have a Z-score higher than 3.

# %%
print(z[55][1])
# Out:
# 3.375038763517309

# %% [raw]
# The data point — 55th record on column ZN is an outlier.

# %% [markdown]
# # 2. IQR score

# %%
Q1 = boston_df.quantile(0.25)
Q3 = boston_df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
#
#      PTRATIO      B  LSTAT
# 0      False  False  False
# 1      False  False  False
# 2      False  False  False
# 3      False  False  False
# 4      False  False  False
# 5      False  False  False
# 6      False  False  False
# 7      False  False  False
# 8      False  False  False
# 9      False  False  False
# 10     False  False  False
# 11     False  False  False
# 12     False  False  False
# 13     False  False  False
# 14     False  False  False
# 15     False  False  False
# 16     False  False  False
# 17     False  False  False
# 18     False   True  False
# 19     False  False  False
# 20     False  False  False
# 21     False  False  False
# 22     False  False  False
# 23     False  False  False
# 24     False  False  False
# 25     False   True  False
# 26     False  False  False
# 27     False   True  False
# 28     False  False  False
# 29     False  False  False
# ..       ...    ...    ...
# 476    False  False  False
# 477    False  False  False
# 478    False  False  False
# 479    False  False  False
# 480    False  False  False
# 481    False  False  False
# 482    False  False  False
# 483    False  False  False
# 484    False  False  False
# 485    False  False  False
# 486    False  False  False
# 487    False  False  False
# 488    False  False  False
# 489    False   True  False
# 490    False   True  False
# 491    False  False  False
# 492    False  False  False
# 493    False  False  False
# 494    False  False  False
# 495    False  False  False
# 496    False  False  False
# 497    False  False  False
# 498    False  False  False
# 499    False  False  False
# 500    False  False  False
# 501    False  False  False
# 502    False  False  False
# 503    False  False  False
# 504    False  False  False
# 505    False  False  False
#
# [506 rows x 13 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-efe69758b143> in <module>()
# ----> 1 print(boston_df < (Q1 - 1.5 * IQR)) |(boston_df > (Q3 + 1.5 * IQR))
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    1557                 self = self.fillna(fill_value)
#    1558
# -> 1559             return self._combine_const(other, na_op, try_cast=True)
#    1560
#    1561     f.__name__ = op_name
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_const(self, other, func, errors, try_cast)
#    4777         new_data = self._data.eval(func=func, other=other,
#    4778                                    errors=errors,
# -> 4779                                    try_cast=try_cast)
#    4780         return self._constructor(new_data)
#    4781
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in eval(self, **kwargs)
#    3685
#    3686     def eval(self, **kwargs):
# -> 3687         return self.apply('eval', **kwargs)
#    3688
#    3689     def quantile(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in eval(self, func, other, errors, try_cast, mgr)
#    1435
#    1436                 raise TypeError('Could not compare [{other!r}] '
# -> 1437                                 'with block values'.format(other=other))
#    1438
#    1439         # transpose if needed
#
# TypeError: Could not compare [None] with block values

# %% [raw]
# The data point where we have False that means these values are valid whereas True indicates presence of an outlier.

# %% [markdown]
# # Working with Outliers: Correcting, Removing

# %% [markdown]
# # 1. Z-score

# %%
boston_df_1 = boston_df[(z < 3).all(axis=1)]
print(boston_df_1)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# 11    0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267   5.0  311.0
# 12    0.09378  12.5   7.87   0.0  0.524  5.889   39.0  5.4509   5.0  311.0
# 13    0.62976   0.0   8.14   0.0  0.538  5.949   61.8  4.7075   4.0  307.0
# 14    0.63796   0.0   8.14   0.0  0.538  6.096   84.5  4.4619   4.0  307.0
# 15    0.62739   0.0   8.14   0.0  0.538  5.834   56.5  4.4986   4.0  307.0
# 16    1.05393   0.0   8.14   0.0  0.538  5.935   29.3  4.4986   4.0  307.0
# 17    0.78420   0.0   8.14   0.0  0.538  5.990   81.7  4.2579   4.0  307.0
# 18    0.80271   0.0   8.14   0.0  0.538  5.456   36.6  3.7965   4.0  307.0
# 19    0.72580   0.0   8.14   0.0  0.538  5.727   69.5  3.7965   4.0  307.0
# 20    1.25179   0.0   8.14   0.0  0.538  5.570   98.1  3.7979   4.0  307.0
# 21    0.85204   0.0   8.14   0.0  0.538  5.965   89.2  4.0123   4.0  307.0
# 22    1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 23    0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952   4.0  307.0
# 24    0.75026   0.0   8.14   0.0  0.538  5.924   94.1  4.3996   4.0  307.0
# 25    0.84054   0.0   8.14   0.0  0.538  5.599   85.7  4.4546   4.0  307.0
# 26    0.67191   0.0   8.14   0.0  0.538  5.813   90.3  4.6820   4.0  307.0
# 27    0.95577   0.0   8.14   0.0  0.538  6.047   88.8  4.4534   4.0  307.0
# 28    0.77299   0.0   8.14   0.0  0.538  6.495   94.4  4.4547   4.0  307.0
# 29    1.00245   0.0   8.14   0.0  0.538  6.674   87.3  4.2390   4.0  307.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 476   4.87141   0.0  18.10   0.0  0.614  6.484   93.6  2.3053  24.0  666.0
# 477  15.02340   0.0  18.10   0.0  0.614  5.304   97.3  2.1007  24.0  666.0
# 478  10.23300   0.0  18.10   0.0  0.614  6.185   96.7  2.1705  24.0  666.0
# 479  14.33370   0.0  18.10   0.0  0.614  6.229   88.0  1.9512  24.0  666.0
# 480   5.82401   0.0  18.10   0.0  0.532  6.242   64.7  3.4242  24.0  666.0
# 481   5.70818   0.0  18.10   0.0  0.532  6.750   74.9  3.3317  24.0  666.0
# 482   5.73116   0.0  18.10   0.0  0.532  7.061   77.0  3.4106  24.0  666.0
# 483   2.81838   0.0  18.10   0.0  0.532  5.762   40.3  4.0983  24.0  666.0
# 484   2.37857   0.0  18.10   0.0  0.583  5.871   41.9  3.7240  24.0  666.0
# 485   3.67367   0.0  18.10   0.0  0.583  6.312   51.9  3.9917  24.0  666.0
# 486   5.69175   0.0  18.10   0.0  0.583  6.114   79.8  3.5459  24.0  666.0
# 487   4.83567   0.0  18.10   0.0  0.583  5.905   53.2  3.1523  24.0  666.0
# 488   0.15086   0.0  27.74   0.0  0.609  5.454   92.7  1.8209   4.0  711.0
# 489   0.18337   0.0  27.74   0.0  0.609  5.414   98.3  1.7554   4.0  711.0
# 490   0.20746   0.0  27.74   0.0  0.609  5.093   98.0  1.8226   4.0  711.0
# 491   0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681   4.0  711.0
# 492   0.11132   0.0  27.74   0.0  0.609  5.983   83.5  2.1099   4.0  711.0
# 493   0.17331   0.0   9.69   0.0  0.585  5.707   54.0  2.3817   6.0  391.0
# 494   0.27957   0.0   9.69   0.0  0.585  5.926   42.6  2.3817   6.0  391.0
# 495   0.17899   0.0   9.69   0.0  0.585  5.670   28.8  2.7986   6.0  391.0
# 496   0.28960   0.0   9.69   0.0  0.585  5.390   72.9  2.7986   6.0  391.0
# 497   0.26838   0.0   9.69   0.0  0.585  5.794   70.6  2.8927   6.0  391.0
# 498   0.23912   0.0   9.69   0.0  0.585  6.019   65.3  2.4091   6.0  391.0
# 499   0.17783   0.0   9.69   0.0  0.585  5.569   73.5  2.3999   6.0  391.0
# 500   0.22438   0.0   9.69   0.0  0.585  6.027   79.7  2.4982   6.0  391.0
# 501   0.06263   0.0  11.93   0.0  0.573  6.593   69.1  2.4786   1.0  273.0
# 502   0.04527   0.0  11.93   0.0  0.573  6.120   76.7  2.2875   1.0  273.0
# 503   0.06076   0.0  11.93   0.0  0.573  6.976   91.0  2.1675   1.0  273.0
# 504   0.10959   0.0  11.93   0.0  0.573  6.794   89.3  2.3889   1.0  273.0
# 505   0.04741   0.0  11.93   0.0  0.573  6.030   80.8  2.5050   1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# 5       18.7  394.12   5.21
# 6       15.2  395.60  12.43
# 7       15.2  396.90  19.15
# 8       15.2  386.63  29.93
# 9       15.2  386.71  17.10
# 10      15.2  392.52  20.45
# 11      15.2  396.90  13.27
# 12      15.2  390.50  15.71
# 13      21.0  396.90   8.26
# 14      21.0  380.02  10.26
# 15      21.0  395.62   8.47
# 16      21.0  386.85   6.58
# 17      21.0  386.75  14.67
# 18      21.0  288.99  11.69
# 19      21.0  390.95  11.28
# 20      21.0  376.57  21.02
# 21      21.0  392.53  13.83
# 22      21.0  396.90  18.72
# 23      21.0  394.54  19.88
# 24      21.0  394.33  16.30
# 25      21.0  303.42  16.51
# 26      21.0  376.88  14.81
# 27      21.0  306.38  17.28
# 28      21.0  387.94  12.80
# 29      21.0  380.23  11.98
# ..       ...     ...    ...
# 476     20.2  396.21  18.68
# 477     20.2  349.48  24.91
# 478     20.2  379.70  18.03
# 479     20.2  383.32  13.11
# 480     20.2  396.90  10.74
# 481     20.2  393.07   7.74
# 482     20.2  395.28   7.01
# 483     20.2  392.92  10.42
# 484     20.2  370.73  13.34
# 485     20.2  388.62  10.58
# 486     20.2  392.68  14.98
# 487     20.2  388.22  11.45
# 488     20.1  395.09  18.06
# 489     20.1  344.05  23.97
# 490     20.1  318.43  29.68
# 491     20.1  390.11  18.07
# 492     20.1  396.90  13.35
# 493     19.2  396.90  12.01
# 494     19.2  396.90  13.59
# 495     19.2  393.29  17.60
# 496     19.2  396.90  21.14
# 497     19.2  396.90  14.10
# 498     19.2  396.90  12.92
# 499     19.2  395.77  15.10
# 500     19.2  396.90  14.33
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [415 rows x 13 columns]

# %% [raw]
# The above code removed around 90+ rows from the dataset i.e. outliers have been removed.

# %% [markdown]
# # 2. IQR Score

# %%
boston_df_out = boston_df[~((boston_df < (Q1 - 1.5 * IQR)) |(boston_df > (Q3 + 1.5 * IQR))).any(axis=1)]
boston_df_out.shape
# Out:
# (274, 13)

# %% [markdown]
# # Missing value treatment and detection

# %% [raw]
# We would be using the wine dataset here..

# %% [markdown]
# # Lets find out the total NAN value in the data

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %% [markdown]
# # Lets drop the null or missing values

# %%
df.dropna()
# Out:
#         Unnamed: 0 country                                        description  \
# 4                4      US  Much like the regular bottling from 2012, this...
# 10              10      US  Soft, supple plum envelopes an oaky structure ...
# 23              23      US  This wine from the Geneseo district offers aro...
# 25              25      US  Oak and earth intermingle around robust aromas...
# 35              35      US  As with many of the Erath 2010 vineyard design...
# 60              60      US  Syrupy and dense, this wine is jammy in plum a...
# 62              62      US  The aromas are brooding, with notes of barrel ...
# 64              64      US  There are intriguing touches to the nose of th...
# 67              67      US  A blend of Merlot and Cabernet Franc, this win...
# 71              71      US  Big oak defines this robustly dense and extrac...
# 73              73      US  Juicy plum, raspberry and pencil lead lead the...
# 74              74      US  This is the producer's first release of this w...
# 75              75      US  This is made from equal parts Cabernet Franc a...
# 78              78      US  Some rosÃ©s are made simply by bleeding the ju...
# 84              84      US  A healthy addition of 13% Petite Sirah provide...
# 87              87      US  Softened tannins surround a light-bodied, lean...
# 90              90      US  This blend of Sangiovese, Malbec, Cabernet Sau...
# 92              92      US  All red Bordeaux varieties are represented in ...
# 94              94      US  Barrel notes are prominent, with aromas of Cre...
# 99              99      US  This blends 20% each of all five red-Bordeaux ...
# 108            108      US  Lots of spearmint, coyote mint, hot licorice, ...
# 111            111      US  This 100% varietal wine opens in a heady aroma...
# 114            114      US  Tar, dried meat, olallieberry and sharp cedar ...
# 116            116      US  The distinctive nose on this bottling is tight...
# 144            144      US  Thick and brooding, this dark, sweetly tannic ...
# 145            145      US  Cooked cranberry is spiced with anise, pepperc...
# 146            146      US  There's a touch of hot asphalt, pencil lead an...
# 147            147      US  Black cherry, black plum and black currant are...
# 149            149      US  Smashed blackberry and blueberry fruit are enh...
# 150            150      US  This wine shows off Yountville fruit at its fi...
# ...            ...     ...                                                ...
# 129815      129815      US  Showing excellent varietal character, this lig...
# 129821      129821      US  Two thirds Tempranillo, this Spanish-style red...
# 129840      129840      US  The entry is oaky and the fruit light; it seem...
# 129854      129854      US  Maldonado is set in a fairly cool area of the ...
# 129855      129855      US  While a minuscule amount of this was made, it ...
# 129857      129857      US  Dusty tannins make for a soft texture in this ...
# 129861      129861      US  This wine brings enchanting aromas of toast, s...
# 129862      129862      US  Earthy forest floor and Asian spice ride atop ...
# 129866      129866      US  This wine is a blend of Cabernet Sauvignon (40...
# 129867      129867      US  Cabernet Sauvignon (84%) makes up the majority...
# 129868      129868      US  This wine is made from a field blend that incl...
# 129869      129869      US  This wine hits the mark, combining intriguing ...
# 129878      129878      US  Light in color and nuanced in oak, this full-b...
# 129879      129879      US  This wine is a blend of 45% Grenache, 37% Syra...
# 129882      129882      US  This wine is mostly Cabernet Sauvignon (78%), ...
# 129891      129891      US  Chocolate, mocha and coconut notes highlight t...
# 129895      129895      US  A blend of vineyards including the winery's Mi...
# 129896      129896      US  Smoothly seductive in texture and body, this m...
# 129898      129898      US  Plum and cherry fruit show on the nose of this...
# 129899      129899      US  Aged entirely in stainless steel, this combine...
# 129904      129904      US  A blend of Sauvignon Blanc, Sauvignon Gris and...
# 129909      129909      US  Hailing from an extreme coastal vineyard, this...
# 129912      129912      US  From the Ranch House block of the famous viney...
# 129913      129913      US  This is taut and dense, and requires time and ...
# 129915      129915      US  The third vintage of Mith is the best yet, com...
# 129919      129919      US  This ripe, rich, almost decadently thick wine ...
# 129926      129926      US  This pure Syrah from Reininger's estate vineya...
# 129945      129945      US  Hailing from one of the more popular vineyards...
# 129949      129949      US  There's no bones about the use of oak in this ...
# 129950      129950      US  This opens with herbaceous dollops of thyme an...
#
#                                     designation  points  price    province  \
# 4            Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 10                              Mountain CuvÃ©e      87   19.0  California
# 23                          Signature Selection      87   22.0  California
# 25                          King Ridge Vineyard      87   69.0  California
# 35                                       Hyland      86   50.0      Oregon
# 60                                       Estate      86  100.0  California
# 62                         Alder Ridge Vineyard      86   25.0  Washington
# 64                                  Golden Horn      86   26.0  California
# 67                                     Inspired      86   46.0  Washington
# 71                                     Old Vine      86   40.0  California
# 73                         Bella Vetta Vineyard      86   75.0  California
# 74                                 Estate Grown      86   55.0  California
# 75                                   The Cypher      86   75.0  California
# 78                                     RosÃ© of      86   25.0      Oregon
# 84                                      Classic      86   24.0  California
# 87                               Blau Vineyards      86   55.0  California
# 90                                        Siena      88   23.0  California
# 92                                   Magnificat      88   55.0  California
# 94      Grand Klasse Reserve Lawrence Vineyards      88   22.0  Washington
# 108           Santa Clara Valley      Central Coast     Matt Kettmann
# 111                   Yountville               Napa    Virginie Boone
# 114                  Paso Robles      Central Coast     Matt Kettmann
# 116            Santa Ynez Valley      Central Coast     Matt Kettmann
# 144     Spring Mountain District               Napa    Virginie Boone
# 145        Santa Lucia Highlands      Central Coast     Matt Kettmann
# 146            Santa Ynez Valley      Central Coast     Matt Kettmann
# 147            Santa Ynez Valley      Central Coast     Matt Kettmann
# 149                     Monterey      Central Coast     Matt Kettmann
# 150                  Napa Valley               Napa    Virginie Boone
# ...                          ...                ...               ...
# 129815       Columbia Gorge (WA)   Washington Other      Paul Gregutt
# 129821      Columbia Valley (WA)    Columbia Valley      Paul Gregutt
# 129840         Rattlesnake Hills    Columbia Valley      Paul Gregutt
# 129854               Napa Valley               Napa    Virginie Boone
# 129855                  Carneros        Napa-Sonoma    Virginie Boone
# 129857                  Carneros        Napa-Sonoma    Virginie Boone
# 129861        Horse Heaven Hills    Columbia Valley  Sean P. Sullivan
# 129862              Green Valley             Sonoma    Virginie Boone
# 129866             Yakima Valley    Columbia Valley  Sean P. Sullivan
# 129867      Columbia Valley (WA)    Columbia Valley  Sean P. Sullivan
# 129868      Russian River Valley             Sonoma    Virginie Boone
# 129869                California   California Other        Jim Gordon
# 129878      Russian River Valley             Sonoma    Virginie Boone
# 129879      Columbia Valley (WA)    Columbia Valley  Sean P. Sullivan
# 129882      Columbia Valley (WA)    Columbia Valley  Sean P. Sullivan
# 129891                 Calistoga               Napa    Virginie Boone
# 129895              Green Valley             Sonoma    Virginie Boone
# 129896          Alexander Valley             Sonoma    Virginie Boone
# 129898               Paso Robles      Central Coast     Matt Kettmann
# 129899               Napa Valley               Napa    Virginie Boone
# 129904                Chalk Hill             Sonoma    Virginie Boone
# 129909    San Luis Obispo County      Central Coast     Matt Kettmann
# 129912              Sonoma Coast             Sonoma    Virginie Boone
# 129913      Columbia Valley (WA)    Columbia Valley      Paul Gregutt
# 129915      Columbia Valley (WA)    Columbia Valley      Paul Gregutt
# 129919   Walla Walla Valley (WA)    Columbia Valley      Paul Gregutt
# 129926   Walla Walla Valley (WA)    Columbia Valley      Paul Gregutt
# 129945         Santa Ynez Valley      Central Coast     Matt Kettmann
# 129949               Napa Valley               Napa    Virginie Boone
# 129950               Napa Valley               Napa    Virginie Boone
#
#        taster_twitter_handle  \
# 4               @paulgwineÂ
# 10                   @vboone
# 23             @mattkettmann
# 25                   @vboone
# 35              @paulgwineÂ
# 60                   @vboone
# 62             @wawinereport
# 64             @mattkettmann
# 67             @wawinereport
# 71                   @vboone
# 73                   @vboone
# 74                   @vboone
# 75                   @vboone
# 78              @paulgwineÂ
# 84                   @vboone
# 87                   @vboone
# 90                   @vboone
# 92                   @vboone
# 94             @wawinereport
# 99                   @vboone
# 108            @mattkettmann
# 111                  @vboone
# 114            @mattkettmann
# 116            @mattkettmann
# 144                  @vboone
# 145            @mattkettmann
# 146            @mattkettmann
# 147            @mattkettmann
# 149            @mattkettmann
# 150                  @vboone
# ...                      ...
# 129815          @paulgwineÂ
# 129821          @paulgwineÂ
# 129867  Bordeaux-style Red Blend                  Tenor
# 129868                     Syrah                  Acorn
# 129869           Sparkling Blend        Biltmore Estate
# 129878                Chardonnay              MacRostie
# 129879                 Red Blend           Maison Bleue
# 129882  Bordeaux-style Red Blend               Matthews
# 129891        Cabernet Sauvignon                    Jax
# 129895                Chardonnay             Martin Ray
# 129896                Chardonnay               Mazzocco
# 129898  Bordeaux-style Red Blend               Midnight
# 129899               White Blend               Paraduxx
# 129904           Sauvignon Blanc             Chalk Hill
# 129909                Pinot Gris                  Derby
# 129912                Pinot Noir                Dunstan
# 129913        Cabernet Sauvignon        Woodward Canyon
# 129915                 Red Blend                 Balboa
# 129919                 Red Blend  Nicholas Cole Cellars
# 129926                     Syrah              Reininger
# 129945              Chenin Blanc              Birichino
# 129949                Chardonnay          Flora Springs
# 129950                 Zinfandel                 Hendry
#
# [22387 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
# Unnamed: 0               129971 non-null int64
# country                  129908 non-null object
# description              129971 non-null object
# designation              92506 non-null object
# points                   129971 non-null int64
# price                    120975 non-null float64
# province                 129908 non-null object
# region_1                 108724 non-null object
# region_2                 50511 non-null object
# taster_name              103727 non-null object
# taster_twitter_handle    98758 non-null object
# title                    129971 non-null object
# variety                  129970 non-null object
# winery                   129971 non-null object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 13.9+ MB

# %% [markdown]
# # Lets fill the missing values with a mean value

# %%
mean_value=df['price'].mean()
df['price']=df['price'].fillna(mean_value)

# %% [markdown]
# # Lets fill the missing values with a median value

# %%
median_value=df['price'].median()
df['price']=df['price'].fillna(median_value)

# %% [markdown]
# # Lets fille the missing values using back fill.

# %%
df.fillna(method='bfill')
# Out:
#         Unnamed: 0      country  \
# 0                0        Italy
# 1                1     Portugal
# 2                2           US
# 3                3           US
# 4                4           US
# 5                5        Spain
# 6                6        Italy
# 7                7       France
# 8                8      Germany
# 9                9       France
# 10              10           US
# 11              11       France
# 12              12           US
# 13              13        Italy
# 14              14           US
# 15              15      Germany
# 16              16    Argentina
# 17              17    Argentina
# 18              18        Spain
# 19              19           US
# 20              20           US
# 21              21           US
# 22              22        Italy
# 23              23           US
# 24              24        Italy
# 25              25           US
# 26              26        Italy
# 27              27        Italy
# 28              28        Italy
# 29              29           US
# ...            ...          ...
# 129941      129941           US
# 129942      129942           US
# 129943      129943        Italy
# 129944      129944       Israel
# 129945      129945           US
# 129946      129946      Germany
# 129947      129947        Italy
# 129948      129948    Argentina
# 129949      129949           US
# 129950      129950           US
# 129951      129951       France
# 129952      129952           US
# 129953      129953  New Zealand
# 129954      129954  New Zealand
# 129955      129955  New Zealand
# 129956      129956  New Zealand
# 129957      129957        Spain
# 129958      129958  New Zealand
# 129959      129959       France
# 129960      129960     Portugal
# 129961      129961        Italy
# 129962      129962        Italy
# 129963      129963       Israel
# 129964      129964       France
# 129965      129965       France
# 129966      129966      Germany
# 129967      129967           US
# 129968      129968       France
# 129969      129969       France
# 129970      129970       France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 21                 Oregon                 Oregon       Oregon Other
# 22      Sicily & Sardinia                Sicilia      Central Coast
# 23             California            Paso Robles      Central Coast
# 24      Sicily & Sardinia                Sicilia             Sonoma
# 25             California           Sonoma Coast             Sonoma
# 26      Sicily & Sardinia        Terre Siciliane     Central Valley
# 27      Sicily & Sardinia        Terre Siciliane     Central Valley
# 28      Sicily & Sardinia  Cerasuolo di Vittoria     Central Valley
# 29             California             Clarksburg     Central Valley
# ...                   ...                    ...                ...
# 129941         California       Mendocino County             Sonoma
# 129942         California          Sonoma County             Sonoma
# 129943  Sicily & Sardinia                Sicilia      Central Coast
# 129944            Galilee      Santa Ynez Valley      Central Coast
# 129945         California      Santa Ynez Valley      Central Coast
# 129946              Mosel        Terre Siciliane               Napa
# 129947  Sicily & Sardinia        Terre Siciliane               Napa
# 129948              Other               San Juan               Napa
# 129949         California            Napa Valley               Napa
# 129950         California            Napa Valley               Napa
# 129951             Alsace                 Alsace               Napa
# 129952         California          Chiles Valley               Napa
# 129953        Hawke's Bay                  Rioja       Oregon Other
# 129954        Marlborough                  Rioja       Oregon Other
# 129955        Marlborough                  Rioja       Oregon Other
# 129956        Hawke's Bay                  Rioja       Oregon Other
# 129957     Northern Spain                  Rioja       Oregon Other
# 129958        Hawke's Bay                 Alsace       Oregon Other
# 129959             Alsace                 Alsace       Oregon Other
# 129960              Douro                Sicilia       Oregon Other
# 129961  Sicily & Sardinia                Sicilia       Oregon Other
# 129962  Sicily & Sardinia                Sicilia       Oregon Other
# 129963            Galilee                 Alsace       Oregon Other
# 129964             Alsace                 Alsace       Oregon Other
# 129965             Alsace                 Alsace       Oregon Other
# 129966              Mosel                 Oregon       Oregon Other
# 129967             Oregon                 Oregon       Oregon Other
# 129968             Alsace                 Alsace                NaN
# 129969             Alsace                 Alsace                NaN
# 129970             Alsace                 Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0          Kerin OâKeefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt          @paulgwineÂ
# 3       Alexander Peartree          @paulgwineÂ
# 4             Paul Gregutt          @paulgwineÂ
# 5        Michael Schachner           @wineschach
# 6          Kerin OâKeefe          @kerinokeefe
# 7               Roger Voss            @vossroger
# 8       Anna Lee C. Iijima            @vossroger
# 9               Roger Voss            @vossroger
# 10          Virginie Boone               @vboone
# 11              Roger Voss            @vossroger
# 12          Virginie Boone               @vboone
# 13         Kerin OâKeefe          @kerinokeefe
# 14           Matt Kettmann         @mattkettmann
# 15      Anna Lee C. Iijima           @wineschach
# 16       Michael Schachner           @wineschach
# 17       Michael Schachner           @wineschach
# 18       Michael Schachner           @wineschach
# 19      Alexander Peartree          @paulgwineÂ
# 20      Alexander Peartree          @paulgwineÂ
# 21            Paul Gregutt          @paulgwineÂ
# 22         Kerin OâKeefe          @kerinokeefe
# 23           Matt Kettmann         @mattkettmann
# 24         Kerin OâKeefe          @kerinokeefe
# 25          Virginie Boone               @vboone
# 26         Kerin OâKeefe          @kerinokeefe
# 27         Kerin OâKeefe          @kerinokeefe
# 28         Kerin OâKeefe          @kerinokeefe
# 29          Virginie Boone               @vboone
# ...                    ...                   ...
# 129941      Virginie Boone               @vboone
Hendry 2012 Blocks 7 & 22 Zinfandel (Napa Valley)
# 129951  Henri Schoenheitz 2012 Holder Gewurztraminer (...
# 129952             Houdini 2011 Zinfandel (Chiles Valley)
# 129953  Mills Reef 2011 Elspeth Cabernet Merlot (Hawke...
# 129954    Ara 2013 Single Estate Pinot Gris (Marlborough)
# 129955            Dog Point 2012 Chardonnay (Marlborough)
# 129956  Esk Valley 2011 Gimblett Gravels Merlot-Cabern...
# 129957          ViÃ±edos Real Rubio 2010 Crianza  (Rioja)
# 129958             Babich 2010 Irongate Red (Hawke's Bay)
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...
# 129960  Caves Transmontanas 2006 VÃ©rtice Pinot Noir (...
# 129961                        COS 2013 Frappato (Sicilia)
# 129962  Cusumano 2012 SÃ gana Tenuta San Giacomo Nero ...
# 129963  Dalton 2012 Oak Aged Cabernet Sauvignon (Galilee)
# 129964  Domaine Ehrhart 2013 Domaine Saint-RÃ©my Herre...
# 129965  Domaine RieflÃ©-Landmann 2013 Seppi Landmann V...
# 129966  Dr. H. Thanisch (Erben MÃ¼ller-Burggraef) 2013...
# 129967                  Citation 2004 Pinot Noir (Oregon)
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970  Domaine Schoffit 2012 Lieu-dit Harth CuvÃ©e Ca...
#
#                          variety                                     winery
# 0                    White Blend                                    Nicosia
# 1                 Portuguese Red                        Quinta dos Avidagos
# 2                     Pinot Gris                                  Rainstorm
# 3                       Riesling                                 St. Julian
# 4                     Pinot Noir                               Sweet Cheeks
# 5             Tempranillo-Merlot                                     Tandem
# 6                       Frappato                            Terre di Giurfo
# 7                GewÃ¼rztraminer                                   Trimbach
# 8                GewÃ¼rztraminer                                Heinz Eifel
# 9                     Pinot Gris                         Jean-Baptiste Adam
# 10            Cabernet Sauvignon                         Kirkland Signature
# 11               GewÃ¼rztraminer                                 Leon Beyer
# 12            Cabernet Sauvignon                           Louis M. Martini
# 13             Nerello Mascalese                        Masseria Setteporte
# 14                    Chardonnay                                   Mirassou
# 15                      Riesling                           Richard BÃ¶cking
# 16                        Malbec                              Felix Lavaque
# 17                        Malbec                              Gaucho Andino
# 18             Tempranillo Blend                                   Pradorey
# 19                      Meritage                               QuiÃ©vremont
# 20                     Red Blend                               QuiÃ©vremont
# 21                    Pinot Noir                                    Acrobat
# 22                   White Blend                         Baglio di Pianetto
# 23                        Merlot                                    Bianchi
# 24                  Nero d'Avola                                 CanicattÃ¬
# 25                    Pinot Noir                        Castello di Amorosa
# 26                   White Blend                                   Stemmari
# 27                  Nero d'Avola                                   Stemmari
# 28                     Red Blend                            Terre di Giurfo
# 29                  Chenin Blanc                    Clarksburg Wine Company
# ...                          ...                                        ...
# 129941                Chardonnay                                    Apriori
# 129942        Cabernet Sauvignon                                   Arrowood
# 129943                 Red Blend            Baglio del Cristo di Campobello
# 129944                    Shiraz                                     Barkan
# 129945              Chenin Blanc                                  Birichino
# 129946                  Riesling             BischÃ¶fliche WeingÃ¼ter Trier
# 129947                 Red Blend                   Feudo Principi di Butera
# 129948                    Malbec                            Finca Las Moras
# 129949                Chardonnay                              Flora Springs
# 129950                 Zinfandel                                     Hendry
# 129951           GewÃ¼rztraminer                          Henri Schoenheitz
# 129952                 Zinfandel                                    Houdini
# 129953           Cabernet Merlot                                 Mills Reef
# 129954                Pinot Gris                                        Ara
# 129955                Chardonnay                                  Dog Point
# 129956  Bordeaux-style Red Blend                                 Esk Valley
# 129957         Tempranillo Blend                        ViÃ±edos Real Rubio
# 129958  Bordeaux-style Red Blend                                     Babich
# 129959                Pinot Gris                          Cave de Turckheim
# 129960                Pinot Noir                        Caves Transmontanas
# 129961                  Frappato                                        COS
# 129962              Nero d'Avola                                   Cusumano
# 129963        Cabernet Sauvignon                                     Dalton
# 129964           GewÃ¼rztraminer                            Domaine Ehrhart
# 129965                Pinot Gris                   Domaine RieflÃ©-Landmann
# 129966                  Riesling  Dr. H. Thanisch (Erben MÃ¼ller-Burggraef)
# 129967                Pinot Noir                                   Citation
# 129968           GewÃ¼rztraminer                            Domaine Gresser
# 129969                Pinot Gris                       Domaine Marcel Deiss
# 129970           GewÃ¼rztraminer                           Domaine Schoffit
#
# [129971 rows x 14 columns]

# %% [markdown]
# # Lets fille the missing values using forward fill.

# %%
df.fillna(method='ffill')
# Out:
#         Unnamed: 0      country  \
# 0                0        Italy
# 1                1     Portugal
# 2                2           US
# 3                3           US
# 4                4           US
# 5                5        Spain
# 6                6        Italy
# 7                7       France
# 8                8      Germany
# 9                9       France
# 10              10           US
# 11              11       France
# 12              12           US
# 13              13        Italy
# 14              14           US
# 15              15      Germany
# 16              16    Argentina
# 17              17    Argentina
# 18              18        Spain
# 19              19           US
# 20              20           US
# 21              21           US
# 22              22        Italy
# 23              23           US
# 24              24        Italy
# 25              25           US
# 26              26        Italy
# 27              27        Italy
# 28              28        Italy
# 29              29           US
# ...            ...          ...
# 129941      129941           US
# 129942      129942           US
# 129943      129943        Italy
# 129944      129944       Israel
# 129945      129945           US
# 129946      129946      Germany
# 129947      129947        Italy
# 129948      129948    Argentina
# 129949      129949           US
# 129950      129950           US
# 129951      129951       France
# 129952      129952           US
# 129953      129953  New Zealand
# 129954      129954  New Zealand
# 129955      129955  New Zealand
# 129956      129956  New Zealand
# 129957      129957        Spain
# 129958      129958  New Zealand
# 129959      129959       France
# 129960      129960     Portugal
# 129961      129961        Italy
# 129962      129962        Italy
# 129963      129963       Israel
# 129964      129964       France
# 129965      129965       France
# 129966      129966      Germany
# 129967      129967           US
# 129968      129968       France
# 129969      129969       France
# 129970      129970       France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# 6       Here's a bright, informal red that opens with ...
# 7       This dry and restrained wine offers spice in p...
# 8       Savory dried thyme notes accent sunnier flavor...
# 9       This has great depth of flavor with its fresh ...
# 10      Soft, supple plum envelopes an oaky structure ...
# 11      This is a dry wine, very spicy, with a tight, ...
# 12      Slightly reduced, this wine offers a chalky, t...
# 13      This is dominated by oak and oak-driven aromas...
# 14      Building on 150 years and six generations of w...
# 15      Zesty orange peels and apple notes abound in t...
# 16      Baked plum, molasses, balsamic vinegar and che...
# 17      Raw black-cherry aromas are direct and simple ...
# 18      Desiccated blackberry, leather, charred wood a...
# 19      Red fruit aromas pervade on the nose, with cig...
# 20      Ripe aromas of dark berries mingle with ample ...
# 129943  Sicily & Sardinia                Sicilia             Sonoma
# 129944            Galilee                Sicilia             Sonoma
# 129945         California      Santa Ynez Valley      Central Coast
# 129946              Mosel      Santa Ynez Valley      Central Coast
# 129947  Sicily & Sardinia        Terre Siciliane      Central Coast
# 129948              Other               San Juan      Central Coast
# 129949         California            Napa Valley               Napa
# 129950         California            Napa Valley               Napa
# 129951             Alsace                 Alsace               Napa
# 129952         California          Chiles Valley               Napa
# 129953        Hawke's Bay          Chiles Valley               Napa
# 129954        Marlborough          Chiles Valley               Napa
# 129955        Marlborough          Chiles Valley               Napa
# 129956        Hawke's Bay          Chiles Valley               Napa
# 129957     Northern Spain                  Rioja               Napa
# 129958        Hawke's Bay                  Rioja               Napa
# 129959             Alsace                 Alsace               Napa
# 129960              Douro                 Alsace               Napa
# 129961  Sicily & Sardinia                Sicilia               Napa
# 129962  Sicily & Sardinia                Sicilia               Napa
# 129963            Galilee                Sicilia               Napa
# 129964             Alsace                 Alsace               Napa
# 129965             Alsace                 Alsace               Napa
# 129966              Mosel                 Alsace               Napa
# 129967             Oregon                 Oregon       Oregon Other
# 129968             Alsace                 Alsace       Oregon Other
# 129969             Alsace                 Alsace       Oregon Other
# 129970             Alsace                 Alsace       Oregon Other
#
#                taster_name taster_twitter_handle  \
# 0          Kerin OâKeefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt          @paulgwineÂ
# 3       Alexander Peartree          @paulgwineÂ
# 4             Paul Gregutt          @paulgwineÂ
# 5        Michael Schachner           @wineschach
# 6          Kerin OâKeefe          @kerinokeefe
# 7               Roger Voss            @vossroger
# 8       Anna Lee C. Iijima            @vossroger
# 9               Roger Voss            @vossroger
# 10          Virginie Boone               @vboone
# 11              Roger Voss            @vossroger
# 12          Virginie Boone               @vboone
# 13         Kerin OâKeefe          @kerinokeefe
# 14           Matt Kettmann         @mattkettmann
# 15      Anna Lee C. Iijima         @mattkettmann
# 16       Michael Schachner           @wineschach
# 17       Michael Schachner           @wineschach
# 18       Michael Schachner           @wineschach
# 19      Alexander Peartree           @wineschach
# 20      Alexander Peartree           @wineschach
# 21            Paul Gregutt          @paulgwineÂ
# 22         Kerin OâKeefe          @kerinokeefe
# 23           Matt Kettmann         @mattkettmann
# 24         Kerin OâKeefe          @kerinokeefe
# 25          Virginie Boone               @vboone
# 26         Kerin OâKeefe          @kerinokeefe
# 27         Kerin OâKeefe          @kerinokeefe
# 28         Kerin OâKeefe          @kerinokeefe
# 29          Virginie Boone               @vboone
# ...                    ...                   ...
# 129941      Virginie Boone               @vboone
# 129942      Virginie Boone               @vboone
# 129943     Kerin OâKeefe          @kerinokeefe
# 129944       Mike DeSimone        @worldwineguys
# 129945       Matt Kettmann         @mattkettmann
# 129946  Anna Lee C. Iijima         @mattkettmann
# 129947     Kerin OâKeefe          @kerinokeefe
# 129948   Michael Schachner           @wineschach
# 129949      Virginie Boone               @vboone
# 129950      Virginie Boone               @vboone
# 129951          Roger Voss            @vossroger
# 129952      Virginie Boone               @vboone
# 129953      Joe Czerwinski                @JoeCz
# 129954      Joe Czerwinski                @JoeCz
# 129955      Joe Czerwinski                @JoeCz
# 129955            Dog Point 2012 Chardonnay (Marlborough)
# 129956  Esk Valley 2011 Gimblett Gravels Merlot-Cabern...
# 129957          ViÃ±edos Real Rubio 2010 Crianza  (Rioja)
# 129958             Babich 2010 Irongate Red (Hawke's Bay)
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...
# 129960  Caves Transmontanas 2006 VÃ©rtice Pinot Noir (...
# 129961                        COS 2013 Frappato (Sicilia)
# 129962  Cusumano 2012 SÃ gana Tenuta San Giacomo Nero ...
# 129963  Dalton 2012 Oak Aged Cabernet Sauvignon (Galilee)
# 129964  Domaine Ehrhart 2013 Domaine Saint-RÃ©my Herre...
# 129965  Domaine RieflÃ©-Landmann 2013 Seppi Landmann V...
# 129966  Dr. H. Thanisch (Erben MÃ¼ller-Burggraef) 2013...
# 129967                  Citation 2004 Pinot Noir (Oregon)
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970  Domaine Schoffit 2012 Lieu-dit Harth CuvÃ©e Ca...
#
#                          variety                                     winery
# 0                    White Blend                                    Nicosia
# 1                 Portuguese Red                        Quinta dos Avidagos
# 2                     Pinot Gris                                  Rainstorm
# 3                       Riesling                                 St. Julian
# 4                     Pinot Noir                               Sweet Cheeks
# 5             Tempranillo-Merlot                                     Tandem
# 6                       Frappato                            Terre di Giurfo
# 7                GewÃ¼rztraminer                                   Trimbach
# 8                GewÃ¼rztraminer                                Heinz Eifel
# 9                     Pinot Gris                         Jean-Baptiste Adam
# 10            Cabernet Sauvignon                         Kirkland Signature
# 11               GewÃ¼rztraminer                                 Leon Beyer
# 12            Cabernet Sauvignon                           Louis M. Martini
# 13             Nerello Mascalese                        Masseria Setteporte
# 14                    Chardonnay                                   Mirassou
# 15                      Riesling                           Richard BÃ¶cking
# 16                        Malbec                              Felix Lavaque
# 17                        Malbec                              Gaucho Andino
# 18             Tempranillo Blend                                   Pradorey
# 19                      Meritage                               QuiÃ©vremont
# 20                     Red Blend                               QuiÃ©vremont
# 21                    Pinot Noir                                    Acrobat
# 22                   White Blend                         Baglio di Pianetto
# 23                        Merlot                                    Bianchi
# 24                  Nero d'Avola                                 CanicattÃ¬
# 25                    Pinot Noir                        Castello di Amorosa
# 26                   White Blend                                   Stemmari
# 27                  Nero d'Avola                                   Stemmari
# 28                     Red Blend                            Terre di Giurfo
# 29                  Chenin Blanc                    Clarksburg Wine Company
# ...                          ...                                        ...
# 129941                Chardonnay                                    Apriori
# 129942        Cabernet Sauvignon                                   Arrowood
# 129943                 Red Blend            Baglio del Cristo di Campobello
# 129944                    Shiraz                                     Barkan
# 129945              Chenin Blanc                                  Birichino
# 129946                  Riesling             BischÃ¶fliche WeingÃ¼ter Trier
# 129947                 Red Blend                   Feudo Principi di Butera
# 129948                    Malbec                            Finca Las Moras
# 129949                Chardonnay                              Flora Springs
# 129950                 Zinfandel                                     Hendry
# 129951           GewÃ¼rztraminer                          Henri Schoenheitz
# 129952                 Zinfandel                                    Houdini
# 129953           Cabernet Merlot                                 Mills Reef
# 129954                Pinot Gris                                        Ara
# 129955                Chardonnay                                  Dog Point
# 129956  Bordeaux-style Red Blend                                 Esk Valley
# 129957         Tempranillo Blend                        ViÃ±edos Real Rubio
# 129958  Bordeaux-style Red Blend                                     Babich
# 129959                Pinot Gris                          Cave de Turckheim
# 129960                Pinot Noir                        Caves Transmontanas
# 129961                  Frappato                                        COS
# 129962              Nero d'Avola                                   Cusumano
# 129963        Cabernet Sauvignon                                     Dalton
# 129964           GewÃ¼rztraminer                            Domaine Ehrhart
# 129965                Pinot Gris                   Domaine RieflÃ©-Landmann
# 129966                  Riesling  Dr. H. Thanisch (Erben MÃ¼ller-Burggraef)
# 129967                Pinot Noir                                   Citation
# 129968           GewÃ¼rztraminer                            Domaine Gresser
# 129969                Pinot Gris                       Domaine Marcel Deiss
# 129970           GewÃ¼rztraminer                           Domaine Schoffit
#
# [129971 rows x 14 columns]

# %% [markdown]
# # In class lab WAP : Perform the summary statistics, required plots using seaborn and matplotlib packages along with the missing value and oulier treatment and detection in the given data set.
#
# # Data set Given - Class grades

# %%
data=pd.read_csv("class-grades.csv")

# %%
data.head()
# Out:
#    Class  Assignment  Tutorial  Midterm  TakeHome  Final
# 0      5       57.14     34.09    64.38     51.48  52.50
# 1      8       95.05    105.49    67.50     99.07  68.33
# 2      8       83.70     83.17    30.00     63.15  48.89
# 3      7       81.22     96.06    49.38    105.93  80.56
# 4      8       91.32     93.64    95.00    107.41  73.89

# %%
data.rename(columns={"Prefix":"Class"},inplace=True)

# %%
data["Final"].skew()
# Out:
# 0.09665593098452334

# %%
data.head()
# Out:
#    Class  Assignment  Tutorial  Midterm  TakeHome  Final
# 0      5       57.14     34.09    64.38     51.48  52.50
# 1      8       95.05    105.49    67.50     99.07  68.33
# 2      8       83.70     83.17    30.00     63.15  48.89
# 3      7       81.22     96.06    49.38    105.93  80.56
# 4      8       91.32     93.64    95.00    107.41  73.89

# %%
sns.lmplot(x='Class',y='Assignment',data=data,scatter=True,fit_reg=True,height=7)
plt.show()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data.describe()
# Out:
#            Class  Assignment    Tutorial     Midterm    TakeHome       Final
# count  99.000000   99.000000   99.000000   99.000000   98.000000   96.000000
# mean    7.313131   85.491717   89.731111   68.049495   80.828469   68.414375
# std     0.932918   12.597694   15.071556   19.376074   23.808806   18.801087
# min     4.000000   28.140000   34.090000   28.120000   16.910000   28.060000
# 25%     7.000000   80.875000   83.350000   52.810000   66.015000   53.122500
# 50%     8.000000   89.940000   93.100000   69.380000   87.960000   66.250000
# 75%     8.000000   95.000000  100.550000   82.810000   98.747500   84.167500
# max     8.000000  100.830000  112.580000  110.000000  108.890000  108.890000

# %%
sns.boxplot(x="Class",y="Tutorial", data=data)
plt.show()

# %%
sns.distplot(data["Class"])

plt.show()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import Series
import matplotlib.pyplot as plt
import seaborn as sns

# %%
NEIC = pd.read_csv('earthquake.csv',sep = ',')
NEIC.shape
# Out:
# (23412, 21)

# %%
NEIC.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type    ...      \
# 0                     NaN        6.0             MW    ...
# 1                     NaN        5.8             MW    ...
# 2                     NaN        6.2             MW    ...
# 3                     NaN        5.8             MW    ...
# 4                     NaN        5.8             MW    ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]
