# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series,DataFrame
import seaborn as sns

# %%
t=sns.load_dataset('titanic')

# %%
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
t.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
t.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1=DataFrame(t.dtypes)

# %%
df1
# Out:
#                     0
# survived        int64
# pclass          int64
# sex            object
# age           float64
# sibsp           int64
# parch           int64
# fare          float64
# embarked       object
# class        category
# who            object
# adult_male       bool
# deck         category
# embark_town    object
# alive          object
# alone            bool

# %%
t.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df1['NUnique']=t.nunique()
df1
# Out:
#                     0  NUnique
# survived        int64        2
# pclass          int64        3
# sex            object        2
# age           float64       88
# sibsp           int64        7
# parch           int64        7
# fare          float64      248
# embarked       object        3
# class        category        3
# who            object        3
# adult_male       bool        2
# deck         category        7
# embark_town    object        3
# alive          object        2
# alone            bool        2

# %%
df1.rename(columns={'dtypes':'Datatypes'},inplace=True)

# %%
df1
# Out:
#             Datatypes  NUnique  count
# survived        int64        2    891
# pclass          int64        3    891
# sex            object        2    891
# age           float64       88    714
# sibsp           int64        7    891
# parch           int64        7    891
# fare          float64      248    891
# embarked       object        3    889
# class        category        3    891
# who            object        3    891
# adult_male       bool        2    891
# deck         category        7    203
# embark_town    object        3    889
# alive          object        2    891
# alone            bool        2    891

# %%
df1['count']=t.count()
df1
# Out:
#                dtypes  NUnique  count
# survived        int64        2    891
# pclass          int64        3    891
# sex            object        2    891
# age           float64       88    714
# sibsp           int64        7    891
# parch           int64        7    891
# fare          float64      248    891
# embarked       object        3    889
# class        category        3    891
# who            object        3    891
# adult_male       bool        2    891
# deck         category        7    203
# embark_town    object        3    889
# alive          object        2    891
# alone            bool        2    891

# %%
#get discribe statistics on "object" datatypes
t.describe(include=['object'])
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
#get describe statistics on "int" datatypes
t.describe(include=['int64'])
# Out:
#          survived      pclass       sibsp       parch
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.523008    0.381594
# std      0.486592    0.836071    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    0.000000
# 50%      0.000000    3.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000    0.000000
# max      1.000000    3.000000    8.000000    6.000000

# %%
#get describe statistics on "float" datatypes
t.describe(include=['float'])
# Out:
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
#get describe statistics on "str" datatypes
t.describe(include=['bool'])
# Out:
#        adult_male alone
# count         891   891
# unique          2     2
# top          True  True
# freq          537   537

# %%
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
#get describe statistics on "float" datatypes
t.describe(include=['number'])
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#Normalisation : Range btw 0 to 1
t.alive.value_counts()

#Standardisation
t.alive.value_counts(normalize=True)

print(t.alive.value_counts())

print('          ')
print('Normalisation :',t.alive.value_counts(normalize=True))
# Out:
# ('Standardisation :', no     549
# yes    342
# Name: alive, dtype: int64)
#
# ('Normalisation :', no     0.616162
# yes    0.383838
# Name: alive, dtype: float64)

# %%
sns.countplot(x= t['age'])

# %%
sns.countplot(x='sex', data=t, hue='survived')

# %%
sns.barplot(x='who',y='fare',data=t)
